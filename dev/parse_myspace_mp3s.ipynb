# %%
import os, re, json, gzip, pickle, shutil

from pydub.utils import mediainfo

# %%
# %config IPCompleter.greedy=True
# %config Completer.use_jedi = False

# %%
#myspace data downloaded from https://archive.org/download/myspace_dragon_hoard_2010 
myspace_metadata_path = '../data/myspace_mp3s/updated-metadata.tsv'
myspace_mp3s_path = '../data/myspace_mp3s'
metadata_path = '%s/metadata.json.gz' % myspace_mp3s_path
genre_cts_path = '%s/genre_cts.pkl' % myspace_mp3s_path
genre_map_path = '%s/genre_map.pkl' % myspace_mp3s_path
mapped_genre_cts_path = genre_cts_path.replace('genre', 'mapped_genre')

# %% [markdown]
# ### Examples of raw metadata records

# %%
#8	The Oisters	136566144	the oi!sters	www.myspace.com/theoistersoioi	0	myspace	675	
#http://cache09-music01.myspacecdn.com/72/std_1e55dd8bd6213ae741667092fe272ea8.mp3	SALT LAKE CITY, Utrecht	
#Punk	1619	1605	840	2008-09-27
with open(myspace_metadata_path, encoding='ISO-8859-1') as f:
    for i in range(5):
        print(f.readline())
# Out:
# 1	Big Yellow Moon	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache06-music02.myspacecdn.com/46/std_1f69563352d19cb0132334cd0d3adeaf.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 2	Flaming Desire	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache08-music02.myspacecdn.com/59/std_db98343d3aaeecdb267624ed12443bfd.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 3	Do You Dream In Colour	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache04-music01.myspacecdn.com/30/std_a5d7357c06cbf627c53dc3a1e9524aa9.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 4	A Buddha For My Brother	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache10-music02.myspacecdn.com/80/std_cbd6477f38e09e1bb1a03cd02d699a73.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 5	Testify	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache10-music02.myspacecdn.com/79/std_727ab6bcb3cc2b7bde234703010a4c60.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 6	Angel in My System	78393366	bill nelson	www.myspace.com/nelsonicausa	0	myspace	25796	http://cache03-music02.myspacecdn.com/21/std_1280256ec82361a9397b79687516e605.mp3	Wakefield, Northwest	Rock,Electronica,Alternative	43248	41762	28382	2009-03-21
#
# 7	Weed and Cheez	136566144	the oi!sters	www.myspace.com/theoistersoioi	0	myspace	675	http://cache05-music01.myspacecdn.com/39/std_8a9d2982bb9752680581d8b8b86f4ebe.mp3	SALT LAKE CITY, Utrecht	Punk	1619	1605	840	2008-09-27
#
# 8	The Oisters	136566144	the oi!sters	www.myspace.com/theoistersoioi	0	myspace	675	http://cache09-music01.myspacecdn.com/72/std_1e55dd8bd6213ae741667092fe272ea8.mp3	SALT LAKE CITY, Utrecht	Punk	1619	1605	840	2008-09-27
#
# 9	Bread Patrol  Live	136566144	the oi!sters	www.myspace.com/theoistersoioi	0	myspace	675	http://cache09-music01.myspacecdn.com/70/std_77b9c4064626263f7e66a133ac382b57.mp3	SALT LAKE CITY, Utrecht	Punk	1619	1605	840	2008-09-27
#
# 10	Laughing In The Sunshine	85706506	preston smith	www.myspace.com/prestonsmithmusic	0	myspace	9392	http://cache09-music01.myspacecdn.com/67/std_d2ce05e978a93495aa90cf14c0f1427f.mp3	Los Angeles, California	Rock,Jazz,Blues	26773	26773	10482	2009-03-28
#
# 11	Oh I Love You So	85706506	preston smith	www.myspace.com/prestonsmithmusic	0	myspace	9392	http://cache04-music01.myspacecdn.com/32/std_d51adc1ec1bcc2055a840e884ddefede.mp3	Los Angeles, California	Rock,Jazz,Blues	26773	26773	10482	2009-03-28
#
# 12	Those Same Old Blues	85706506	preston smith	www.myspace.com/prestonsmithmusic	0	myspace	9392	http://cache05-music01.myspacecdn.com/34/std_da165ad64f53cdf5637f7eb95e1da8de.mp3	Los Angeles, California	Rock,Jazz,Blues	26773	26773	10482	2009-03-28
#
# 13	The Ways Of Sin	85706506	preston smith	www.myspace.com/prestonsmithmusic	0	myspace	9392	http://cache03-music01.myspacecdn.com/19/std_5f2d5040ecb3e38bdde8ee7dbba2fa68.mp3	Los Angeles, California	Rock,Jazz,Blues	26773	26773	10482	2009-03-28
#
# 14	Ah Ti Ta Ti Ta Ta	49122552	alex chilton	www.myspace.com/lxchilton	0	myspace	59101	http://cache04-music01.myspacecdn.com/28/std_9b91aabae67ee569a7af5c857b0cc005.mp3	MEMPHIS, Tennessee	Soul,Rock,Pop	64874	64874	63582	2008-10-18
#
# 15	Take Me Home And Make Me	49122552	alex chilton	www.myspace.com/lxchilton	0	myspace	59101	http://cache04-music01.myspacecdn.com/26/std_af9b8a343ff851dbb2ee6f2a95cfe905.mp3	MEMPHIS, Tennessee	Soul,Rock,Pop	64874	64874	63582	2008-10-18
#
# 16	What's Your Sign Girl	49122552	alex chilton	www.myspace.com/lxchilton	0	myspace	59101	http://cache03-music01.myspacecdn.com/17/std_1a76cee496599bb95f2f6a5c3af156e4.mp3	MEMPHIS, Tennessee	Soul,Rock,Pop	64874	64874	63582	2008-10-18
#
# 17	Like Flies On Sherbert	49122552	alex chilton	www.myspace.com/lxchilton	0	myspace	59101	http://cache03-music01.myspacecdn.com/22/std_c8d7f29987e702ec8aafe47bd598613a.mp3	MEMPHIS, Tennessee	Soul,Rock,Pop	64874	64874	63582	2008-10-18
#
# 18	Will Come	158701165	daniel dee	www.myspace.com/djdanieldee	0	myspace	2162	http://cache11-music01.myspacecdn.com/81/std_c9d3c9acaedca4cc5ba4a0b7ff90e7f1.mp3	Roma, 	Techno,Trance,Progressive	8897	8897	2442	2009-03-10
#
# 19	Movimento	158701165	daniel dee	www.myspace.com/djdanieldee	0	myspace	2162	http://cache10-music01.myspacecdn.com/75/std_55439ab1e5e9e05d5e34662a0e1c4114.mp3	Roma, 	Techno,Trance,Progressive	8897	8897	2442	2009-03-10
#
# 20	Line Up	158701165	daniel dee	www.myspace.com/djdanieldee	0	myspace	2162	http://cache10-music01.myspacecdn.com/79/std_ba0ae53250599876968cbc78a9b909ed.mp3	Roma, 	Techno,Trance,Progressive	8897	8897	2442	2009-03-10

# %% [markdown]
# ### Extract fields of interest from metadata, format, and store

# %%
def parse_myspace_data(myspace_metadata_path, out_metadata_path, genre_cts_path):
    data = {}
    genre_cts = {}
    zip_cts = {}
    
    with open(myspace_metadata_path, encoding='ISO-8859-1') as f:
        for line in f:
            rec = {}
            
            mp3_filepath = ''
            
            line = line.replace('\n', '')
            items = line.split('\t')
            
            rec['song_name'] = format_text(items[1])
            rec['artist_name'] = format_text(items[3])
            
            #http://cache09-music01.myspacecdn.com/72/std_1e55dd8bd6213ae741667092fe272ea8.mp3
            zip_file, mp3_name = items[8].split('/')[-2:]
            
            rec['mp3_zipname'] = zip_file
            if zip_file not in zip_cts:
                zip_cts[zip_file]=0
            zip_cts[zip_file]+=1
            
            rec['mp3_filename'] = mp3_name
            
            mp3_filepath = '%s/%s' % (zip_file, mp3_name)
            
            genres = [format_text(g) for g in items[10].split(',')]
            for g in genres:
                if not g in genre_cts:
                    genre_cts[g]=0
                genre_cts[g]+=1
            rec['genres'] = genres
            
            data[mp3_filepath] = rec
            
    print('writing %d records' % len(data))
    with gzip.open(out_metadata_path, 'wt', encoding='utf-8') as oz:
        json.dump(data, oz)

    print('writing %d genre counts' % len(genre_cts))
    with open(genre_cts_path, 'wb') as o:
        pickle.dump(genre_cts, o)
            
    return myspace_data, genre_cts, zip_cts
            
    
def format_text(text):
    return text.strip().lower().replace(' ', '_').replace('&amp;', '&')


def load_metadata(path):
    with gzip.open(path, 'rt', encoding='utf-8') as fz:
        metadata = json.load(fz)
    return metadata


def load_genre_cts(path):
    with open(path, 'rb') as f:
        genre_cts = pickle.load(f)
    return genre_cts

# %%
if not os.path.exists(metadata_path):
    data, genre_cts, zip_cts = parse_myspace_data(myspace_metadata_path, metadata_path, genre_cts_path)
else:
    print('loading metadata and genre cts')
    data = load_metadata(metadata_path)
    genre_cts = load_genre_cts(genre_cts_path)
    
#(488550, 127, 490273), zips: 1-64 have almost 5K each, 65-80 have 8-9K each, 81+ have 5K each
len(data), len(genre_cts)
# Out:
# loading metadata and genre cts
# (488550, 126)

# %% [markdown]
# ### Normalize genres - map highly specific genres to general genres, e.g. 'hardcore' -> 'metal'
# #### Note that each song can have up to 3 genres assigned

# %%
#raw genre counts

for g in sorted(genre_cts, key=genre_cts.get, reverse=True):
    print('%s\t%d' % (g, genre_cts[g]))
# Out:
# rock	116064
# pop	58329
# 	58023
# hip_hop	55815
# alternative	47577
# indie	47185
# metal	36043
# rap	35438
# experimental	34023
# electronica	33994
# punk	33108
# acoustic	32511
# other	29262
# r&b	26140
# jazz	20789
# folk	20677
# electro	20514
# hardcore	19669
# soul	18380
# progressive	16699
# house	15645
# techno	14071
# blues	13902
# psychedelic	13886
# ambient	13456
# reggae	13042
# country	13039
# folk_rock	12938
# funk	11796
# death_metal	11003
# latin	9949
# powerpop	8755
# industrial	8241
# trance	7954
# thrash	7788
# christian	7758
# club	7724
# classical	7373
# garage	7276
# pop_punk	6936
# classic_rock	6816
# gothic	6752
# roots_music	6245
# black_metal	6109
# americana	5809
# new_wave	5613
# drum_&_bass	5304
# ska	5247
# dub	4996
# down-tempo	4825
# comedy	4682
# breakbeat	4163
# nu-jazz	3990
# grindcore	3727
# lounge	3556
# melodramatic_popular_song	3556
# lyrical	3545
# afro-beat	3334
# fusion	3320
# disco_house	3285
# crunk	3268
# minimalist	3190
# southern_rock	3106
# rockabilly	3051
# jam_band	3001
# emo	2828
# healing_&_easylistening	2813
# electroacoustic	2784
# surf	2757
# trip_hop	2754
# freestyle	2706
# shoegaze	2664
# post_punk	2620
# tropical	2567
# a'cappella	2561
# idm	2545
# glam	2500
# bluegrass	2497
# grunge	2319
# grime	2219
# visual	2211
# reggaeton	2107
# gospel	2015
# live_electronics	1912
# celtic	1909
# 2-step	1904
# progrsv_house	1819
# screamo	1716
# regional_mexican	1693
# big_beat	1659
# psychobilly	1622
# turntablism	1575
# jungle	1545
# showtunes	1488
# ghettotech	1405
# christian_rap	1355
# happy_hardcore	1290
# concrete	1261
# hard_house	1220
# neo-soul	1218
# swing	1206
# bossa_nova	1186
# zouk	1101
# hyphy	1095
# acousmatic	923
# tape_music	923
# german_pop	892
# spanish_pop	891
# j-pop	828
# western_swing	812
# classical_-_opera_and_vocal	779
# italian_pop	768
# hawaiian	749
# salsa	694
# flamenco	687
# emotronic	654
# breakcore	644
# japanese_classic_music	572
# samba	540
# tango	532
# idol	529
# chinese_pop	479
# k-pop	428
# chinese_traditional	314
# religious	116
# french_pop	98
# dutch_pop	86

# %%
def map_genres(genre_cts, min_examples=1000):
    genre_map = {}
    
    #map subtypes to types with substrings
    substrs = ['punk', 'jazz', 'reggae', 'disco', 'house', 'rap', 'classical', 
               'metal', 'folk', 'pop', 'rock']
    for g in genre_cts:
        for substr in substrs:
            if substr in g and g not in genre_map:
                print('%s -> %s' % (g, substr))
                genre_map[g] = substr
                
    genre_map['rockabilly'] = 'oldies'
    print('rockabilly -> oldies')
    
    #various other mappings
    map_to = 'metal'
    for g in ['hardcore', 'thrash', 'grindcore', 'screamo', 'happy_hardcore']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'punk'
    for g in ['psychobilly']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'classical'
    for g in ["a'cappella", 'choral', 'chamber_music', 'baroque', 'medieval', 'renaissance', 'symphonic', 
              'opera', 'vocal', 'ensemble', 'piano', 'guitar', 'solo_instruments', 'woodwinds', 'strings']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'hip_hop'
    for g in ['crunk', 'trip_hop', 'hyphy', 'west_coast', 'east_coast', 'contemporary_urban']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to      
            
    map_to = 'dance'
    for g in ['club', 'idm', '2-step', 'big_beat', 'grime', 'breakcore', 'freestyle', 'trance', 'techno',
              'turntablism', 'breakbeat', 'dub', 'drum_&_bass', 'ghettotech']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to  
    
    map_to = 'electronic'
    for g in ['electronica', 'electro', 'live_electronics', 'emotronic']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to        
    
    map_to = 'alternative'
    for g in ['grunge', 'ska', 'garage', 'shoegaze', 'indie', 'alternative_general']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
    
    map_to = 'oldies'
    for g in ['rockabilly', 'surf', 'soft_rock', 'adult_contemporary', 'swing', 'swing/big_band', 'western_swing',
              'love_songs', 'lounge', 'aaa/adult_alternative', 'oldies', 'standards', 
              'crooners/vocals', 'romantic', 'rock-n-roll_oldies']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'jazz'
    for g in ['soul', 'neo-soul', 'fusion', 'world_fusion', 'detroit', 'bebop', 'mod']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'blues'
    for g in ['r&b']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'rock'
    for g in ['psychedelic', 'acid', 'glam', 'jam_band']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to

    map_to = 'spiritual'
    for g in ['gospel', 'spiritual', 'christian', 'religious']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'pop'
    for g in ['idol', 'lyrical', 'contemporary', 'crossover', 'alternative_cover_songs']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'ambient'
    for g in ['down-tempo', 'mood_music', 'new_age']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
    
    map_to = 'experimental'
    for g in ['concrete', 'visual', 'minimal', 'minimalist', 'experimental', 'noise', 
              'abstract', 'tape_music', 'acousmatic', 'electroacoustic']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'funk'
    for g in ['funk', 'funky_breaks', 'groove']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'goth'
    for g in ['goth_rock', 'darkwave', 'new_wave', 'emo', 'goth', 'gothic']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    map_to = 'rap'
    for g in ['new_school', 'old_school']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
    
    #just lumping these together
    map_to = 'world'
    for g in ['zouk', 'chinese_traditional', 'japanese_classic_music', 'salsa', 'samba', 'latin', 'flamenco',
              'bossa_nova', 'jungle', 'regional_mexican', 'celtic', 'tropical', 'afro-beat', 'roots_music',
              'world/folk_cover_songs', 'general_latin', 'asian', 'americana', 'world_traditions', 
              'native_american', 'tribal', 'caribbean', 'african', 'brazilian',  'hawaiian',
              'russian', 'indian', 'jewish/israeli', 'french', 'nouveau_flamenco', 'cuban', 'arabic',
              'merengue', 'scandinavian', 'european', 'south/central_american', 'tango',
              'traditional', 'quebecois', ]:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
    #map types of spoken word
    map_to = 'spoken_word'
    for g in ['humor', 'comedy', 'parodies', 'general_comedy', 'political_humor', 'satire', 'spoofs', 'bodily_functions', 
              'dumb_stories', 'lies', 'speak_your_mind', 'paranormal', 'aliens', 'witchcraft', 
              'self-help', 'mental_health', 'stories_and_myths', 'horror_stories', 'movies', 'audio_books', 
              'interviews', 'poetry', 'spoken_word', 'politics', 'shout_outs', 'commercials', 'recorded_greetings', 
              'opinions', 'education', 'emergency!', 'nonfiction', 
              'hypnosis', 'advice', 'radio', 'time_capsule_recordings', 'love']:
        if g not in genre_map:
            print('%s -> %s' % (g, map_to))
            genre_map[g] = map_to
            
            
    #direct remappings
    genre_map['healing_&_easylistening'] = 'easy_listening'
            
        
    #add remaining if there are enough instances
    for g,c in genre_cts.items():
        if not g.strip():
            continue
        if g not in genre_map:
            if min_examples and c<min_examples:
                continue
            print('%s -> %s' % (g, g))
            genre_map[g] = g
            
    return genre_map


def get_unique_mapped_genres(genre_map):
    return list(set([g for g in genre_map.values()]))

    
def get_mapped_genre_cts(mapped_genre_cts_path, genre_map):
    mapped_genre_cts = {g:0 for g in genre_map.values()}
    for g, mg in genre_map.items():
        if g not in genre_cts:
            continue
        mapped_genre_cts[mg]+=genre_cts[g]


    with open(mapped_genre_cts_path.replace('.pkl', '.txt'), 'w') as o:
        for g in sorted(mapped_genre_cts, key=mapped_genre_cts.get, reverse=True):
            print('%s\t%s' % (g, mapped_genre_cts[g]))
            o.write('%s\t%s\n' % (g, mapped_genre_cts[g]))

    with open(mapped_genre_cts_path, 'wb') as o:
        pickle.dump(mapped_genre_cts, o)
        
    return mapped_genre_cts


def read_genre_map(genre_map_path):
    with open(genre_map_path, 'rb') as f:
        genre_map = pickle.load(f)
    return genre_map


def write_genre_map(genre_map, genre_map_path):
    with open(genre_map_path, 'wb') as o:
         pickle.dump(genre_map, o)
    with open(genre_map_path.replace('.pkl', '.txt'), 'w') as o:
        for g in sorted(genre_map, key=genre_map.get):
            o.write('%s\t%s\n' % (g, genre_map[g]))

# %%
if os.path.exists(genre_map_path):
    print('loading genre map')
    genre_map = read_genre_map(genre_map_path)
else:
    genre_map = map_genres(genre_cts, min_examples=0)
    write_genre_map(genre_map, genre_map_path)

for rg,g in genre_map.items():
    print('%s -> %s' % (rg,g))
# Out:
# loading genre map
# rock -> rock
# punk -> punk
# jazz -> jazz
# pop -> pop
# rap -> rap
# reggae -> reggae
# black_metal -> metal
# folk -> folk
# metal -> metal
# death_metal -> metal
# j-pop -> pop
# post_punk -> punk
# house -> house
# classical_-_opera_and_vocal -> classical
# folk_rock -> folk
# hard_house -> house
# pop_punk -> punk
# powerpop -> pop
# classical -> classical
# rockabilly -> oldies
# nu-jazz -> jazz
# classic_rock -> rock
# italian_pop -> pop
# spanish_pop -> pop
# disco_house -> disco
# melodramatic_popular_song -> pop
# southern_rock -> rock
# reggaeton -> reggae
# chinese_pop -> pop
# k-pop -> pop
# german_pop -> pop
# progrsv_house -> house
# christian_rap -> rap
# dutch_pop -> pop
# french_pop -> pop
# hardcore -> metal
# thrash -> metal
# grindcore -> metal
# screamo -> metal
# happy_hardcore -> metal
# psychobilly -> punk
# a'cappella -> classical
# choral -> classical
# chamber_music -> classical
# baroque -> classical
# medieval -> classical
# renaissance -> classical
# symphonic -> classical
# opera -> classical
# vocal -> classical
# ensemble -> classical
# piano -> classical
# guitar -> classical
# solo_instruments -> classical
# woodwinds -> classical
# strings -> classical
# crunk -> hip_hop
# trip_hop -> hip_hop
# hyphy -> hip_hop
# west_coast -> hip_hop
# east_coast -> hip_hop
# contemporary_urban -> hip_hop
# club -> dance
# idm -> dance
# 2-step -> dance
# big_beat -> dance
# grime -> dance
# breakcore -> dance
# freestyle -> dance
# trance -> dance
# techno -> dance
# turntablism -> dance
# breakbeat -> dance
# dub -> dance
# drum_&_bass -> dance
# ghettotech -> dance
# electronica -> electronic
# electro -> electronic
# live_electronics -> electronic
# emotronic -> electronic
# grunge -> alternative
# ska -> alternative
# garage -> alternative
# shoegaze -> alternative
# indie -> alternative
# alternative_general -> alternative
# surf -> oldies
# soft_rock -> oldies
# adult_contemporary -> oldies
# swing -> oldies
# swing/big_band -> oldies
# western_swing -> oldies
# love_songs -> oldies
# lounge -> oldies
# aaa/adult_alternative -> oldies
# oldies -> oldies
# standards -> oldies
# crooners/vocals -> oldies
# romantic -> oldies
# rock-n-roll_oldies -> oldies
# soul -> jazz
# neo-soul -> jazz
# fusion -> jazz
# world_fusion -> jazz
# detroit -> jazz
# bebop -> jazz
# mod -> jazz
# r&b -> blues
# psychedelic -> rock
# acid -> rock
# glam -> rock
# jam_band -> rock
# gospel -> spiritual
# spiritual -> spiritual
# christian -> spiritual
# religious -> spiritual
# idol -> pop
# lyrical -> pop
# contemporary -> pop
# crossover -> pop
# alternative_cover_songs -> pop
# down-tempo -> ambient
# mood_music -> ambient
# new_age -> ambient
# concrete -> experimental
# visual -> experimental
# minimal -> experimental
# minimalist -> experimental
# experimental -> experimental
# noise -> experimental
# abstract -> experimental
# tape_music -> experimental
# acousmatic -> experimental
# electroacoustic -> experimental
# funk -> funk
# funky_breaks -> funk
# groove -> funk
# goth_rock -> goth
# darkwave -> goth
# new_wave -> goth
# emo -> goth
# goth -> goth
# gothic -> goth
# new_school -> rap
# old_school -> rap
# zouk -> world
# chinese_traditional -> world
# japanese_classic_music -> world
# salsa -> world
# samba -> world
# latin -> world
# flamenco -> world
# bossa_nova -> world
# jungle -> world
# regional_mexican -> world
# celtic -> world
# tropical -> world
# afro-beat -> world
# roots_music -> world
# world/folk_cover_songs -> world
# general_latin -> world
# asian -> world
# americana -> world
# world_traditions -> world
# native_american -> world
# tribal -> world
# caribbean -> world
# african -> world
# brazilian -> world
# hawaiian -> world
# russian -> world
# indian -> world
# jewish/israeli -> world
# french -> world
# nouveau_flamenco -> world
# cuban -> world
# arabic -> world
# merengue -> world
# scandinavian -> world
# european -> world
# south/central_american -> world
# tango -> world
# traditional -> world
# quebecois -> world
# humor -> spoken_word
# comedy -> spoken_word
# parodies -> spoken_word
# general_comedy -> spoken_word
# political_humor -> spoken_word
# satire -> spoken_word
# spoofs -> spoken_word
# bodily_functions -> spoken_word
# dumb_stories -> spoken_word
# lies -> spoken_word
# speak_your_mind -> spoken_word
# paranormal -> spoken_word
# aliens -> spoken_word
# witchcraft -> spoken_word
# self-help -> spoken_word
# mental_health -> spoken_word
# stories_and_myths -> spoken_word
# horror_stories -> spoken_word
# movies -> spoken_word
# audio_books -> spoken_word
# interviews -> spoken_word
# poetry -> spoken_word
# spoken_word -> spoken_word
# politics -> spoken_word
# shout_outs -> spoken_word
# commercials -> spoken_word
# recorded_greetings -> spoken_word
# opinions -> spoken_word
# education -> spoken_word
# emergency! -> spoken_word
# nonfiction -> spoken_word
# hypnosis -> spoken_word
# advice -> spoken_word
# radio -> spoken_word
# time_capsule_recordings -> spoken_word
# love -> spoken_word
# healing_&_easylistening -> easy_listening
# alternative -> alternative
# blues -> blues
# progressive -> progressive
# hip_hop -> hip_hop
# other -> other
# acoustic -> acoustic
# country -> country
# industrial -> industrial
# ambient -> ambient
# bluegrass -> bluegrass
# showtunes -> showtunes

# %%
#unique mapped genres

gs = get_unique_mapped_genres(genre_map)
len(gs), gs
# Out:
# (32,
#  ['progressive',
#   'punk',
#   'showtunes',
#   'folk',
#   'house',
#   'metal',
#   'rap',
#   'dance',
#   'classical',
#   'ambient',
#   'country',
#   'acoustic',
#   'world',
#   'blues',
#   'hip_hop',
#   'oldies',
#   'funk',
#   'jazz',
#   'disco',
#   'reggae',
#   'electronic',
#   'experimental',
#   'industrial',
#   'goth',
#   'alternative',
#   'spoken_word',
#   'pop',
#   'spiritual',
#   'rock',
#   'bluegrass',
#   'other',
#   'easy_listening'])

# %%
# get counts for mapped genres

if not os.path.exists(mapped_genre_cts_path):
    mapped_genre_cts = get_mapped_genre_cts(mapped_genre_cts_path, genre_map)
else:
    print('loading mapped genre cts')
    with open(mapped_genre_cts_path, 'rb') as f:
        mapped_genre_cts = pickle.load(f)
len(mapped_genre_cts)
# Out:
# loading mapped genre cts
# 32

# %% [markdown]
# ### Unzip a test directory and see if metadata recs can be mapped to songs

# %%
def search_zip(folder_path, folder_name, data, genre_map):
    missing = []
    found = []
    genres = {}
    comb_genres={}
    for fn, meta in data.items():
        if fn.startswith('%s/' % folder_name):
            fp = '%s/%s' % (folder_path, fn)
            if not os.path.exists(fp):
                missing.append(meta)
            else:
                found.append(meta)
                if not 'genres' in meta:
                    continue
                
                for g in meta['genres']:
                    if not g:
                        continue
                    g = genre_map[g]
                    if not g in genres:
                        genres[g]=0
                    genres[g]+=1
                
                gs = ', '.join(set([genre_map[g] for g in meta['genres'] if g]))
                if not gs in comb_genres:
                    comb_genres[gs]=0
                comb_genres[gs]+=1
                
    print('missing: %d, found: %d, genres: %d, genre combos: %d' % (len(missing), len(found), len(genres), len(comb_genres)))
    
    return missing, found, genres, comb_genres

# %%
folder_name='1'
missing, found, genres, comb_genres = search_zip(myspace_mp3s_path, folder_name, data, genre_map)
# Out:
# missing: 101, found: 4705, genres: 32, genre combos: 1062

# %%
#genre counts for this zip
[(g, genres[g]) for g in sorted(genres, key=genres.get, reverse=True)]
# Out:
# [('rock', 1378),
#  ('alternative', 1049),
#  ('metal', 944),
#  ('pop', 701),
#  ('electronic', 534),
#  ('dance', 515),
#  ('hip_hop', 499),
#  ('jazz', 460),
#  ('punk', 441),
#  ('experimental', 409),
#  ('world', 364),
#  ('blues', 332),
#  ('folk', 319),
#  ('acoustic', 302),
#  ('rap', 285),
#  ('other', 280),
#  ('progressive', 163),
#  ('ambient', 163),
#  ('goth', 158),
#  ('house', 151),
#  ('reggae', 133),
#  ('funk', 116),
#  ('country', 115),
#  ('classical', 99),
#  ('spiritual', 92),
#  ('oldies', 90),
#  ('industrial', 85),
#  ('spoken_word', 47),
#  ('disco', 30),
#  ('bluegrass', 25),
#  ('easy_listening', 18),
#  ('showtunes', 10)]

# %%
#unique assigned genre combination counts
[(g, comb_genres[g]) for g in sorted(comb_genres, key=comb_genres.get, reverse=True)][:100]
# Out:
# [('', 699),
#  ('metal', 204),
#  ('rock', 116),
#  ('alternative, rock', 80),
#  ('hip_hop, rap', 65),
#  ('other', 53),
#  ('punk, metal', 53),
#  ('alternative, pop, rock', 49),
#  ('alternative', 49),
#  ('hip_hop, blues, rap', 48),
#  ('rock, metal', 47),
#  ('hip_hop', 45),
#  ('rock, alternative', 43),
#  ('pop', 43),
#  ('electronic, dance', 42),
#  ('punk', 41),
#  ('electronic, house, dance', 36),
#  ('rock, pop', 35),
#  ('jazz', 34),
#  ('rock, pop, alternative', 34),
#  ('dance', 33),
#  ('world', 30),
#  ('reggae', 28),
#  ('rock, punk', 26),
#  ('rock, punk, metal', 25),
#  ('rock, punk, alternative', 24),
#  ('progressive, metal', 24),
#  ('rap', 23),
#  ('alternative, acoustic, folk', 23),
#  ('rock, alternative, metal', 23),
#  ('electronic', 22),
#  ('alternative, punk', 21),
#  ('alternative, pop', 19),
#  ('acoustic', 19),
#  ('blues', 18),
#  ('experimental', 18),
#  ('hip_hop, rap, dance', 18),
#  ('rock, progressive', 17),
#  ('rock, pop, acoustic', 17),
#  ('house, dance', 16),
#  ('folk', 16),
#  ('blues, jazz', 16),
#  ('alternative, rock, punk', 15),
#  ('pop, world', 15),
#  ('spiritual', 15),
#  ('electronic, house', 14),
#  ('alternative, punk, metal', 14),
#  ('alternative, folk', 14),
#  ('pop, acoustic, folk', 14),
#  ('rock, acoustic, alternative', 14),
#  ('rock, progressive, metal', 14),
#  ('acoustic, folk', 14),
#  ('alternative, rock, experimental', 13),
#  ('rock, alternative, progressive', 13),
#  ('country', 13),
#  ('jazz, funk', 12),
#  ('electronic, ambient, experimental', 12),
#  ('rock, electronic, pop', 12),
#  ('hip_hop, electronic, dance', 12),
#  ('hip_hop, rap, metal', 11),
#  ('alternative, electronic, experimental', 11),
#  ('rock, experimental', 11),
#  ('rock, blues', 11),
#  ('alternative, pop, acoustic', 11),
#  ('acoustic, folk, world', 11),
#  ('hip_hop, alternative, rap', 10),
#  ('spoken_word', 10),
#  ('jazz, world', 10),
#  ('hip_hop, jazz, blues', 10),
#  ('rock, jazz, pop', 10),
#  ('hip_hop, blues', 10),
#  ('electronic, ambient', 10),
#  ('hip_hop, blues, pop', 10),
#  ('rock, pop, folk', 10),
#  ('blues, jazz, pop', 9),
#  ('hip_hop, rap, world', 9),
#  ('alternative, electronic, pop', 9),
#  ('pop, electronic, experimental', 9),
#  ('industrial, metal', 9),
#  ('pop, rock', 9),
#  ('alternative, electronic', 9),
#  ('folk, world', 9),
#  ('pop, goth, electronic', 8),
#  ('rock, goth, punk', 8),
#  ('goth, metal', 8),
#  ('rock, pop, punk', 8),
#  ('hip_hop, jazz, funk', 8),
#  ('blues, rock', 8),
#  ('hip_hop, jazz, rap', 8),
#  ('rock, jazz', 8),
#  ('rock, goth, metal', 8),
#  ('rock, folk', 8),
#  ('rock, funk, alternative', 8),
#  ('rock, country, folk', 8),
#  ('industrial, electronic', 8),
#  ('alternative, hip_hop, rap', 7),
#  ('hip_hop, blues, reggae', 7),
#  ('pop, jazz', 7),
#  ('alternative, folk, experimental', 7),
#  ('rock, pop, spiritual', 7)]

# %% [markdown]
# ### Sort mp3s into genre folders by majority mapped genre

# %%
def sort_into_genre_folders(folder_path, folder_name, data, genre_map, mapped_genre_cts):
    genres = {g:0 for g in genre_map.values()}
    for fn, meta in data.items():
        zip_number, fn = fn.split('/')
        if zip_number == folder_name:
            fp = '%s/%s/%s' % (folder_path, zip_number, fn)
            if not os.path.exists(fp):
                continue
            if not 'genres' in meta or not meta['genres']:
                continue

            g = [genre_map[g] for g in meta['genres'] if g in genre_map]
            if not g:
                continue
                
            use_genre = g[0]
            for gn in g:
                if g.count(gn)>1:
                    use_genre = gn
                    break
            g = use_genre
            
            genres[g]+=1
            gp = '%s/%s/%s' % (folder_path, zip_number, g)
            if not os.path.exists(gp):
                print('make %s for %s with %s' % (gp, fn, meta['genres']))
                os.mkdir(gp)
            nfp = '%s/%s' % (gp, fn)
            shutil.move(fp, nfp)
            
    os.mkdir('%s/%s/unknown' % (folder_path, folder_name))
    for fn in os.listdir('%s/%s' % (folder_path, folder_name)):
        if fn.endswith('.mp3'):
            fp = '%s/%s/%s' % (folder_path, folder_name, fn)
            nfp = '%s/%s/unknown/%s' % (folder_path, folder_name, fn)
            shutil.move(fp, nfp)
            
    print([(g, genres[g]) for g in sorted(genres, key=genres.get, reverse=True)])
    
    
def resort_into_genre_folders(folder_path, folder_name, metadata, genre_map):
    genres = {g:0 for g in genre_map.values()}
    moved=0
    same=0
    zip_path = folder_path + '/' + folder_name
    for genre in os.listdir(zip_path):
        if genre=='unknown':
            continue
        
        genre_path = '%s/%s' % (zip_path, genre)
        print(genre_path)
        
        for fn in os.listdir(genre_path):
            if not fn.endswith('.mp3'):
                continue

            fp = '%s/%s' % (genre_path, fn)

            zip_num_filename = '%s/%s' % (folder_name, fn)
            if zip_num_filename not in metadata:
                print('not in meta', zip_num_filename)
                continue

            meta = metadata[zip_num_filename]
            if not 'genres' in meta or not meta['genres']:
                continue

            g = [genre_map[g] for g in meta['genres'] if g in genre_map]
            if not g:
                continue

            use_genre = g[0]
            for gn in g:
                if g.count(gn)>1:
                    use_genre = gn
                    break
            g = use_genre
            genres[g]+=1
            
            gp = '%s/%s' % (zip_path, g)
            
            if not os.path.exists(gp):
                print('make %s for %s with %s' % (gp, fn, meta['genres']))
                os.mkdir(gp)
                
            nfp = '%s/%s' % (gp, fn)
            if not fp==nfp:
                moved+=1
                print('moving', fp,nfp)
                shutil.move(fp, nfp)
            else:
                same+=1
            
    print('same',same,'moved', moved, [(g, genres[g]) for g in sorted(genres, key=genres.get, reverse=True)])

# %%
folder_name = '78'
sort_into_genre_folders(myspace_mp3s_path, folder_name, data, genre_map, mapped_genre_cts)
#resort_into_genre_folders(myspace_mp3s_path, folder_name, data, genre_map)
# Out:
# make ../data/myspace_mp3s/78/oldies for std_4bf3ebe144cfab872e7cb43b9ec9fc55.mp3 with ['lounge']
# make ../data/myspace_mp3s/78/dance for std_e572d0535f38b8308859d947046db8d6.mp3 with ['club', 'techno', 'electronica']
# make ../data/myspace_mp3s/78/alternative for std_01ef82f028003febd357313487187cb5.mp3 with ['indie', 'rock', 'alternative']
# make ../data/myspace_mp3s/78/country for std_4aec55c1ef9cf8d0fb912af95446f34d.mp3 with ['country']
# make ../data/myspace_mp3s/78/rap for std_aec2502e7bae03238d7ce65b39f51cbf.mp3 with ['rap']
# make ../data/myspace_mp3s/78/punk for std_9b3cfa92d088e951cdc28a7c3a0769df.mp3 with ['pop_punk']
# make ../data/myspace_mp3s/78/hip_hop for std_6ff68840058176f92bf875c023aad775.mp3 with ['hip_hop', 'drum_&_bass', 'funk']
# make ../data/myspace_mp3s/78/jazz for std_25b5aadf629fddf11495c45b92d407da.mp3 with ['soul', 'hip_hop', 'electronica']
# make ../data/myspace_mp3s/78/metal for std_9f548292754db18eb8662937b4280561.mp3 with ['metal', 'hardcore', 'rock']
# make ../data/myspace_mp3s/78/rock for std_207f010f0b0d299fa1d805dcd6cdcf54.mp3 with ['rock', 'electronica']
# make ../data/myspace_mp3s/78/reggae for std_3561941159b8d49060c72a03e72893ed.mp3 with ['reggae']
# make ../data/myspace_mp3s/78/other for std_1b25392e8b0d87218f575a32de8caa74.mp3 with ['other', 'folk', 'country']
# make ../data/myspace_mp3s/78/electronic for std_54ee0d323d02da0c625c81a8c5296be3.mp3 with ['electronica', 'alternative', 'industrial']
# make ../data/myspace_mp3s/78/pop for std_5ece647cec7b1796889db16c35d2929c.mp3 with ['pop', 'electro', 'funk']
# make ../data/myspace_mp3s/78/world for std_f1637cc45b535432759e05b3b74f0f14.mp3 with ['latin', 'regional_mexican', 'progressive']
# make ../data/myspace_mp3s/78/experimental for std_cc258c0adf213cae17d1afd98740c10a.mp3 with ['experimental', 'electronica', 'shoegaze']
# make ../data/myspace_mp3s/78/disco for std_115cb09cb2d0ad802518649ecd266e00.mp3 with ['disco_house', 'disco_house', 'disco_house']
# make ../data/myspace_mp3s/78/blues for std_33b20875e1db942d0c9c9b825114e09f.mp3 with ['r&b', 'pop', 'alternative']
# make ../data/myspace_mp3s/78/ambient for std_1f74e01993001539055b17fad6e6c485.mp3 with ['ambient', 'electronica', 'alternative']
# make ../data/myspace_mp3s/78/progressive for std_9aa715e9770ef5961e662d9d4473a1b3.mp3 with ['progressive', 'electronica', 'house']
# make ../data/myspace_mp3s/78/folk for std_593cb867bee3eb424001a686f1b32780.mp3 with ['folk', 'jazz', 'blues']
# make ../data/myspace_mp3s/78/spiritual for std_94271a5fdcb5fd27beda6369300808d0.mp3 with ['christian']
# make ../data/myspace_mp3s/78/house for std_bc50ad2b66144c6718c600e6565c2d68.mp3 with ['house', 'christian']
# make ../data/myspace_mp3s/78/classical for std_4bd61d687e0341cffac18b7eead52ce3.mp3 with ['classical', 'acoustic']
# make ../data/myspace_mp3s/78/bluegrass for std_b1568c36a559bc52802c57498fd4f616.mp3 with ['bluegrass', 'folk_rock', 'jam_band']
# make ../data/myspace_mp3s/78/goth for std_ecaaa361c4fd5e607febe860f37de05c.mp3 with ['emo', 'pop_punk', 'surf']
# make ../data/myspace_mp3s/78/funk for std_c0c2208998c311c02f21cca6e62b8f4c.mp3 with ['funk', 'acoustic', 'blues']
# make ../data/myspace_mp3s/78/spoken_word for std_2aefaf02493917a3e8c17bf86948519a.mp3 with ['comedy', 'comedy', 'comedy']
# make ../data/myspace_mp3s/78/easy_listening for std_60ea7b80e4bec51008d352634398946b.mp3 with ['healing_&_easylistening', 'acoustic', 'hawaiian']
# make ../data/myspace_mp3s/78/showtunes for std_24a2cf0c8e80c6eef2af1dcddbbc7048.mp3 with ['showtunes', 'showtunes', 'showtunes']
# make ../data/myspace_mp3s/78/acoustic for std_3107e4fce1b4566eb7cebc9861b4950b.mp3 with ['acoustic', 'country', 'folk_rock']
# make ../data/myspace_mp3s/78/industrial for std_d540f9484014a5097162d7c2ae625676.mp3 with ['industrial']
# [('rock', 1244), ('alternative', 938), ('metal', 789), ('rap', 624), ('dance', 558), ('pop', 512), ('jazz', 457), ('hip_hop', 452), ('other', 325), ('experimental', 316), ('world', 241), ('electronic', 238), ('folk', 184), ('punk', 177), ('blues', 165), ('ambient', 116), ('reggae', 111), ('goth', 69), ('house', 66), ('acoustic', 64), ('country', 56), ('classical', 45), ('spiritual', 36), ('oldies', 30), ('progressive', 26), ('spoken_word', 20), ('funk', 18), ('easy_listening', 14), ('showtunes', 5), ('disco', 4), ('bluegrass', 4), ('industrial', 3)]

# %%
for fn in os.listdir('%s/%s/metal' % (myspace_mp3s_path, folder_name)):
    fp = '%s/%s' % (folder_name, fn)
    if fp not in data:
        print(fp, 'not found in data')
        continue
    meta = data[fp]
    print('%s\t%s\t%s\t%s' % (fn, meta['artist_name'], meta['song_name'], meta['genres']))
# Out:
# std_00302ad2489630819f64a2c35aa9729d.mp3	hell_within	shadows_of_vanity	['metal', 'hardcore', 'thrash']
# std_0058505adce0279aaf5a6f528aebc516.mp3	eden_weint_im_grab	undine_sey_meyn_schutzgeyst	['metal', 'black_metal', 'gothic']
# std_006c145cea29e3c93ab331c882d82f97.mp3	slobodan_kajkut	20_minutes_for_2000_euros	['thrash']
# std_008eb15c3483e41094c623e3e4978a37.mp3	crisis_bureau	automated_response	['hardcore', 'punk']
# std_01314a7de97020d6e9ed1f03f8023ebd.mp3	temple_of_baal	living_fleshthrone	['death_metal', 'black_metal', 'thrash']
# std_017d2af5d22af87b62865d9fd8bc65ea.mp3	before_the_dawn	my_darkness	['metal', 'progressive', 'gothic']
# std_01be1a490d6a169801e864080b962244.mp3	acrid_asphyxiation_(rip)	intestine_jigsaw_puzzle	['grindcore', 'hardcore', 'death_metal']
# std_01c73027bb5c37ba1230b909a5ff4766.mp3	odd_squad	welcome_wagon	['hardcore', 'punk']
# std_01d41805d0565ad89b2bf0a2069e681d.mp3	membranes_of_the_multiverse	frustration	['grindcore', 'hardcore', 'death_metal']
# std_024f49f17df0758d84be4e5b9fb30441.mp3	tempo_38	the_secret_weapon	['hardcore', 'rock', 'punk']
# std_02986bae42dc5685a6d5dfc9d5cf0ae5.mp3	oracle_sun	lost_in_silence	['metal']
# std_029b0f3debf31d308a04ddd2668b393c.mp3	prosper_or_perish_(new_song_up!)	anywhere_but_here	['metal', 'hardcore']
# std_02d2d8264f6a5d93acb5fb89f80fda66.mp3	back_to_back	famous	['hardcore', 'hardcore', 'punk']
# std_038fcda9b1fc4ae60143f99e89017b3b.mp3	antaeus	blood_libels	['black_metal']
# std_03e30394f90647fe24e668d13f0cc47f.mp3	new_society	strangers_the_likeness	['metal', 'electronica', 'industrial']
# std_040688fa763fae7b634b7f7300c89bcd.mp3	silberbach	terror_aus_fleisch_und_blut	['black_metal']
# std_049edeb6ba3dadee492174ca0a6c1e7d.mp3	monty_cantsin	krautkillah	['thrash']
# std_04b3c21fb82495263b8e80612b16ac37.mp3	leichenwetter	klage	['metal', 'alternative', 'gothic']
# std_059957f568611a216f7277f98b06399e.mp3	in-quest_(in_writing_mode)	cryotron_frequency	['metal', 'death_metal', 'progressive']
# std_05a5a5a6c9e2aa0c0b64342304f191c6.mp3	dark_matter	labor	['metal', 'alternative', 'industrial']
# std_066b6b468faab3a410180d728ad87dc9.mp3	insurreccion_al_morir	hambre_de_justicia	['metal', 'latin', 'rock']
# std_069e60d51928fd298980d98c5dcf3de2.mp3	losa_(aint_dead,_ya_hear)	madness	['metal', 'experimental', 'rock']
# std_078c3c025d47f241c57c054f1b846cd7.mp3	malevolent_creation	premature_burial	['death_metal', 'thrash']
# std_07f8b75cea50504d4e6a9bd77007895d.mp3	ten-13	first_to_be	['metal', 'rock', 'new_wave']
# std_086446333208b061e887be6974535e07.mp3	instant_agony	exploitation	['hardcore', 'punk', 'punk']
# std_08976aced825a53b76634808ff32f367.mp3	anand_clique_now_on_free.napster.com	mountain	['metal', 'hardcore', 'thrash']
# std_09304dec77586781f507a8b20af50427.mp3	malodorous	debauched_putrefaction	['grindcore', 'death_metal', 'experimental']
# std_0984bdd7011e31a1a06d464958ade2b6.mp3	fist_of_fury	do_it_again	['hardcore', 'hardcore', 'hardcore']
# std_09c3680a3b08372005abc33eb5d40502.mp3	lost_in_tears	new_dawn__demo	['metal']
# std_0a2e536733c0b6bffee09f23d69a300f.mp3	helmskey_(has_a_song_up!)	black_disharmonium	['death_metal', 'black_metal', 'thrash']
# std_0aa7e2b10fd84cf2b43c84664a971ae1.mp3	j_church	not_given_lightly	['hardcore', 'powerpop', 'punk']
# std_0abc7d44599982d4bce6b974083b1bb8.mp3	odd_project	a_heros_trial	['metal', 'rock', 'alternative']
# std_0af17c3f6aea829a76b44cf560f60cc5.mp3	kitty_litter_disco	welcome_to_the_kld	['hardcore']
# std_0b654aeb0ed74798b0b1620d7d3123ab.mp3	offside	street_kids	['hardcore', 'rock', 'punk']
# std_0c5dc1e2176583dcd2bdb6c80327bd92.mp3	the_mantors_(more_music)_ãâ©ãâ®	shit_machine	['metal', 'death_metal', 'black_metal']
# std_0cee0ca39583bbdc822704c568d67d4e.mp3	ichorid_(is_coming_back?)	30_seconds_of_fury	['metal', 'grindcore', 'death_metal']
# std_0d79adf8a122c33e2b4d8d5d7520f5ce.mp3	60_grit	in_your_eyes	['metal', 'death_metal', 'southern_rock']
# std_0e02fdf682e8b6e4bedc303120b801eb.mp3	deathwitch	necrosodomizer	['death_metal', 'black_metal', 'thrash']
# std_0e47e9436afa8caa6ebdb3dbff72044a.mp3	pest_productions	zuriaake	['black_metal']
# std_0f0194fd4295b9fc9e50d1155cf401a6.mp3	cauterized	freedom_fighters	['metal', 'grindcore', 'death_metal']
# std_0f5adcbfce909defe3eac7c5accb9a8e.mp3	blockheads	silent	['grindcore', 'hardcore', 'punk']
# std_10bb3614c6ba47169120e8b2cb2d98fd.mp3	betrayal_(new_songs_posted_&_pre-order_the_ep!)	running_on_empty	['metal', 'hardcore', '2-step']
# std_11a15578310d281cb3b576ba136b3801.mp3	autumn_leaves_fall	fall_of_paris	['metal', 'rock']
# std_124aa1e78246efb512e9dbc3efc78d54.mp3	faustcoven	caravan_of_plague_bearers	['metal', 'down-tempo', 'black_metal']
# std_12bf28ce0fc3649314cf40357a8b3a74.mp3	take_my_word_(2006-2008)	sellout_chic_rough_mix	['hardcore', 'punk']
# std_13a5ee6c5b67b86eca05a6e939fabc62.mp3	phantom-x	join_the_revolution	['metal']
# std_14a10737e17c5c8e9576980a2bf589f8.mp3	am_i_dead_yet!_(r.i.p)	rough_mix_3o_sec	['screamo', 'hardcore']
# std_156bef0a8404ae0d51297ba05b98ae4f.mp3	running_potatoes	te_equivocas	['hardcore', 'punk', 'ska']
# std_1596617dccfb79d34ea3e679eeb1e210.mp3	inimenter	can_we_die_now_please	['metal', 'rock', 'alternative']
# std_15b1ad17f149dd73e3f75ad76f4626c8.mp3	antimaniax	war_story_xainamitna_version	['hardcore', 'punk', 'ska']
# std_165a559787c5357d2bfe5f8c8e30ab37.mp3	the_turbomen	lady_double_dealer	['metal', 'rock', 'southern_rock']
# std_1669271da38a98c7ceb371f26d64efbd.mp3	necronoclast	monument_to_the_dead	['black_metal']
# std_16cb4be1b6402ce263ed98a7a33720a2.mp3	grey_cell_green	train_of_thought	['metal', 'rock', 'progressive']
# std_17bcc04d708d773e90998a89829af5a8.mp3	overmars	obsolete	['hardcore', 'down-tempo', 'alternative']
# std_18bce9879f0ae9c24b6e7c3563ac920d.mp3	the_mad_thrashers	your_america	['grindcore', 'hardcore', 'punk']
# std_1931c061211e5a4b00abb48c2da489d1.mp3	proven	heaven	['metal', 'hardcore', 'thrash']
# std_199e29f7e6b53c6588985bf96567ab86.mp3	after_the_burial_{new_album_in_stores_now}	berzerker	['metal', 'hardcore', 'progressive']
# std_1b1d67a0cb5c89d24fddf8ace690db25.mp3	loch_vostok	humanitix	['metal', 'progressive']
# std_1b40d28301b869a71646145f53b20937.mp3	liar_of_golgotha	the_proliferation	['black_metal']
# std_1c3cb598e2638ebecfb6b2cd575283c5.mp3	neglect	fuck_life	['metal', 'hardcore', 'thrash']
# std_1cc3c133a3a88ce3dcb11e6191a8b3d7.mp3	the_bleedout	manchurian_candidates	['metal', 'hardcore', 'death_metal']
# std_1dc8303919b3fdcd1ce40bd85c45ca3e.mp3	sanctity	beneath_the_machine	['metal', 'metal', 'thrash']
# std_1dd08c2eb12294748f69c97f159ba4c8.mp3	divine_rapture	world_of_shit	['metal', 'death_metal', 'black_metal']
# std_1df5e33d8e8760a701976bb08ea0e764.mp3	throne_of_molok_::_last_t-shirts_still_available!	thehorde_of_thermonuclearsatan	['metal', 'hardcore', 'industrial']
# std_1e0eb7ff0f5f80878d2042c9e8d8432d.mp3	starter_kit	last_call_you_win	['metal', 'rock', 'alternative']
# std_1f27086653dda1c7cfa77b1ba3aae3da.mp3	in_winter	in_the_garden	['metal', 'electronica', 'industrial']
# std_1f4bac16c621586afbd705c6991d73e4.mp3	draxsis	sparrows_tale	['metal', 'rock', 'alternative']
# std_211ef46ec2fbf7558e2ebd74ebaf8a8f.mp3	janus_stark	barriers	['metal']
# std_2146362123fc4b08ad4ee9a78952c712.mp3	chiaroscura	as_thick_as_thieves	['metal', 'progressive', 'thrash']
# std_21514a063f0fea72c62e6faa24f41739.mp3	ainmatter	apoplectic	['metal', 'death_metal', 'drum_&_bass']
# std_21901c28f08db06f178326f578f5afaf.mp3	sunflowers_hc	looking	['hardcore', 'punk']
# std_21b75cd7bf63a7c3eccb0ea6b56a1872.mp3	erilaz	new_world_disorder	['metal', 'folk', 'industrial']
# std_21c253e29eb07323e2a1177346717c4f.mp3	artery__eruption	screams_from_the_disemboweled	['metal', 'grindcore', 'death_metal']
# std_22492752c2f844fe94bd451e05dfb7df.mp3	exilia_(mixing_in_l.a.!!!)	kill_me	['metal', 'rock']
# std_22a0fc49bcfd40aeedc64a6ecff50261.mp3	vokodlok	blestem	['metal', 'death_metal', 'black_metal']
# std_2340adb8bb2fc034ad31d7bc41131aa0.mp3	divinity_destroyed_(is_auditioning_drummers)	haven	['metal', 'experimental', 'progressive']
# std_23c5de737a86e8c8c835617aa8d0ea6e.mp3	the_county_medical_examiners	morgagnic_anatomics	['grindcore', 'death_metal']
# std_23c9fc41e9503986212a9c9f4cdff7ad.mp3	the_threat_remains	wasted_nation_demo	['metal', 'hardcore', 'thrash']
# std_23d06776e58f5bdde61750b66a427f3b.mp3	watchmaker	lice_crawling_humanity	['metal', 'black_metal', 'thrash']
# std_258e103588f73adc50ec768d4532004a.mp3	waltari	wish_i_could_heal	['metal', 'rock', 'alternative']
# std_25edab92f3ecf1f9a13bbbaee8ba200f.mp3	detonation	structural_deceit	['metal', 'death_metal', 'thrash']
# std_26290e538966e156c28508e7a3724818.mp3	the_sound_and_the_fury_(new_blog,_new_song!)	the_reply	['hardcore', 'rock', 'christian']
# std_263de5d2e78d16010e804997dffb1d2c.mp3	falling_forward	unfinished_song	['hardcore', 'rock', 'alternative']
# std_268ccc33283cab966b0ffb4ab5f982a6.mp3	skylines	liars_and_saints	['metal', 'hardcore', 'rock']
# std_26c0b8e3b83fd1f8c4129673a0d96ceb.mp3	a.o.a.(axis_of_ascendancy)_2xcd_available	is_this_life	['hardcore', 'punk', 'thrash']
# std_275b3953189f25897245790d463e7900.mp3	kilpi	nerokasta_ikv	['metal']
# std_2796dcbcfd88281f495ee8949a928b62.mp3	vilkates	ruler	['black_metal']
# std_279f687ca74c48c29522f1c1e173145c.mp3	demonoid	firestorms	['death_metal', 'thrash']
# std_29297b9a057869e1f557bee9b74dd340.mp3	split_image	jovial	['metal', 'hardcore', 'punk']
# std_296f5eea2f156bc8296f770c3f312a9a.mp3	demon_hunter,_new_album_out_now!	not_ready_to_die	['metal', 'hardcore', 'christian']
# std_29d24ce09e73af3023407acbb6aa2348.mp3	crydebris	vertigo	['metal', 'hardcore', 'experimental']
# std_2b1b2ec9c0e9a20ca7dd6a06b1777131.mp3	for_my_pain...	rapture_of_lust	['metal', 'rock', 'gothic']
# std_2b6adaa8fe6b2f1765186a46bb180c39.mp3	youth_in_asia	come_undone	['screamo', 'experimental', 'rock']
# std_2c6aa1d25eab1f6428312b1f89b05362.mp3	grotesque_formation	purging_decayed_afterlife	['grindcore', 'death_metal', 'lounge']
# std_2cab2080abd8c3e68e0a874c1a6aef9f.mp3	pale_creation	bleed_the_soil	['metal', 'hardcore', 'rock']
# std_2ccf9c03087cb8ab0ea8c34ebc9066e6.mp3	galilee!_(stoked_for_tbts/writing!)	old_chastisement	['metal', 'progressive', 'christian']
# std_2d0151877dcec81de5312ae0d6f2a1dd.mp3	jud_jud	x_harmonics_song_x	['hardcore', 'thrash']
# std_2de4dc071bb2a67e9bce01c8043807c8.mp3	lionsgate	evil_game	['metal']
# std_2e60d382ccf486f60cd397a06f7aab6c.mp3	valse_triste	siivutettu_etu	['hardcore', 'punk']
# std_2e79edfe7ee792c2184b7244577d7265.mp3	lujuria_[con_nuevo_single_listo_para_descargar!!]	impotencia_criminal	['metal', 'rock']
# std_2ee324cad0bd73f38aa4689203ba9e68.mp3	madnomad	the_drunkard's_song	['screamo', 'regional_mexican', 'showtunes']
# std_2f1d4044b1c78f9fdcd340276e29a079.mp3	prawda-records_(new_cwill-song_added!)	cwill_imprisonment	['metal', 'hardcore', 'punk']
# std_2f4d1e83cfdef8a73e21ca6449ce8008.mp3	tristania	tender_trip_on_earth	['metal', 'alternative', 'gothic']
# std_306f3a3cc512eadf9e17d4b6ecde43df.mp3	horn_of_dagoth	thunder_of_hoof_and_steel	['metal', 'black_metal', 'black_metal']
# std_30803925d53e2749b18cc6fb98b4aeb6.mp3	marian_gold	dance_with_me	['hardcore']
# std_30dc402943c7ae9b7a6075e66ab381ca.mp3	corpus	change	['metal', 'rock', 'alternative']
# std_310ace88e012e9a3348d506a567ee820.mp3	la_rumeur_des_chaines	le_baptistere	['metal', 'black_metal']
# std_3116545b61fa69b0a99c6a767d552e0d.mp3	end-time_illusion_(dialysis_is_imminent)	a_day_of_rest	['metal', 'death_metal', 'thrash']
# std_31bb5e143751d07c441fec3716b9775e.mp3	impulse_manslaughter	they_start_the_war	['grindcore', 'hardcore', 'punk']
# std_3203de74b4b7a53e86b0d110ae1411d0.mp3	rudra	ananda	['death_metal', 'black_metal', 'thrash']
# std_3356e24b81cd3aa9a3eb726004664492.mp3	stereotypical_working_class	sorrow	['metal', 'rock']
# std_3359dd5d2a6245227e831f676f930816.mp3	e.t.t.s.__is_dead!	manhandle_your_vagina	['metal', 'grindcore', 'death_metal']
# std_33f9d651f6af76db740f75eb164f1f4b.mp3	electric_frankenstein	super_kool	['metal', 'rock', 'punk']
# std_349675ce1416723e3b19f24277bb964a.mp3	luciferian_recording_new_album	supreme_infernal_legions	['metal', 'death_metal', 'black_metal']
# std_3507dd1d29a581782d0ecb55ca23b5cd.mp3	rush_limbaugh	conservatives	['hardcore']
# std_370d753004ecb623c1c29048ccb2ebe6.mp3	craig_goldy	one_more_for_the_road	['metal', 'classic_rock']
# std_373ae25bfd99987e17a76e82c5231e42.mp3	rusty_cooley	dark_matter	['metal', 'metal', 'metal']
# std_379c64d230ce0975aa00d6ce1f2a2df1.mp3	mena_brinno	metal_meltdown	['metal', 'folk', 'gothic']
# std_3835d1fe360c3c3b5d34be10af971576.mp3	seiden_valles	come_show_me	['metal', 'hardcore']
# std_384c3de15333582511766458bd67d80f.mp3	andy_winter	bodies_without_organs	['metal', 'progressive', 'classical']
# std_399828e3a769cc7345922ec7dfcb5058.mp3	sick_of_it_all	machete	['hardcore']
# std_3a4c088aac727e9b6d7b2da369d8d4d6.mp3	the_spudmonsters	pressure	['metal', 'hardcore', 'thrash']
# std_3a61110dbea93682876685d4537b092a.mp3	the_epidemic_and_her_plague[rip]	reach_for_the_sky	['metal', 'hardcore']
# std_3a78d1125a0cebcbb8545710b4bd063d.mp3	exodus__-___(the_atrocity_exhibition__out_now!_)	44_magnum_opus	['metal', 'death_metal', 'thrash']
# std_3b26983ff9d11759f0d4ed06aa6fa4ed.mp3	hirilorn	the_legion_that_will_never_fal	['metal', 'death_metal', 'black_metal']
# std_3b78240161a3aa3d02ece3138038531a.mp3	etched_in_red	led	['metal', 'rock', 'progressive']
# std_3be8bca056166e0b57bb1f75e3655685.mp3	sophya	benedicto_xvi	['metal', 'death_metal', 'black_metal']
# std_3c08d51730247dbc967ceb968ccddeb8.mp3	mercury_switch	landslide_2007_demo	['metal', 'hardcore', 'rock']
# std_3c893d03e697dbb4ac7b379134be6701.mp3	loits	aeg_argata	['metal', 'rock', 'black_metal']
# std_3d0f95dd72ffdf4165808cb5d54ed796.mp3	armor_for_the_broken	a_collision_in_slow_motion	['metal', 'hardcore', 'experimental']
# std_3e26e60841ccf7370eb1dc8300860490.mp3	schismopathic	economic_danger	['grindcore', 'grindcore', 'grindcore']
# std_3ecd2f9ab6c6c735d82669aeabae90f5.mp3	eternal_oath	fallen_virtue	['metal', 'gothic']
# std_3f70a3e12e6b3f31e83ec65da7059cd9.mp3	sacred_reich	surf_nicaragua	['metal', 'hardcore', 'thrash']
# std_3f776cee4d91bacdffb4842a383e6d44.mp3	biomekkanik	state_of_perfection	['metal', 'emo', 'alternative']
# std_3ff3ebdeee20e60fc940a0f8bbc3d1c6.mp3	ethan_novak	money_makes_you	['metal', 'rock', 'shoegaze']
# std_404d78892c4456340d40c624ba03f60e.mp3	a_ravens_forest	1837	['black_metal']
# std_408a0414928c456247140de73cb9eca8.mp3	daylight_dies	last_alone	['metal']
# std_408b7b513bca6311983a63d18a8fc0e1.mp3	maximum_penalty	threat_assessment	['metal', 'hardcore']
# std_4090f6e450c38a9409c4ef179ec2e602.mp3	pks	killing_machines	['metal', 'hardcore', 'experimental']
# std_416c24d48e19b37bf80bca468a507485.mp3	pyuria_-_searching_drummer_&_new_song_online!!!	blind_victim	['grindcore', 'death_metal', 'thrash']
# std_421de86e9faf2f293c50ac8bfb8e4265.mp3	intense_hammer_rage	siamese_sluts_of_fused_flesh	['death_metal', 'christian_rap', 'hawaiian']
# std_4281bf6852d210aef03f62acda018dde.mp3	hardcore_united	yellow_lemon_tree	['hardcore']
# std_429c9649d42b7a7b66f097a0abbf345d.mp3	ambervoid	hello_deadface	['metal', 'experimental', 'progressive']
# std_42f3f08d7b12a3f11c31f6d13f0852cd.mp3	southern_cross	the_third_gate	['metal', 'progressive', 'thrash']
# std_43e8ef54c7ea575294fde8e5b3d79191.mp3	pitiful_reign	thrash_boobs_and_zombies	['metal', 'thrash']
# std_44612ce81ddcfaade59714bf08c7f0b0.mp3	psytronix	man_in_the_cauldron	['metal', 'rock', 'pop']
# std_4541989e4fc3a70df61a650d0387166a.mp3	tatort_toilet	dein_firewire_brennt	['happy_hardcore', 'punk', 'jungle']
# std_45468431208f35ba4ad8b1193a4d9e4c.mp3	black_snake_moan	the_slow	['metal', 'gothic', 'industrial']
# std_458d35d4565231deff6b53cce8af145d.mp3	kerbdog	mexican_wave	['metal', 'rock', 'grunge']
# std_45e0f6706105315269eb41655c66cf4e.mp3	tears_for_the_dying	disease	['happy_hardcore', 'down-tempo', 'nu-jazz']
# std_466d4a946e1a6083e387e138345783db.mp3	lizzard	lune	['metal', 'experimental', 'rock']
# std_471c10a7be4d44d1e1e57e5802b1cfbe.mp3	rex_mundi	whispers_of_my_soul	['metal', 'progressive']
# std_4741e4a5b78b6c9ddbef70bde5705aea.mp3	rising_dust	don't_burn_the_witch	['metal', 'rock']
# std_49116b89954d5800e558b773bd6deeac.mp3	amplifire	drown_together	['metal', 'rock', 'grunge']
# std_4983cc6f8fb1e6fb1c8c70faecddeab5.mp3	diecast	hourglass	['metal', 'hardcore', 'rock']
# std_49b740281d667bbdbf5d724bda6f0e9b.mp3	krimson_reign	blood_for_blood_old_shit	['metal', 'hardcore', 'death_metal']
# std_4be0aca15b49b336903fd2aee7531290.mp3	viboras	big_dreams	['hardcore', 'rock', 'punk']
# std_4cff23aa13e6c72b8d042580574adbf1.mp3	smashed_face_-_looking_for_second_cd_reedition!	i_despise_you	['grindcore', 'hardcore', 'death_metal']
# std_4daac70e871be369601b9fbc51f3b335.mp3	decapitation_station	plague_of_1197	['metal', 'powerpop', 'comedy']
# std_4e2d7cf5205562b4f8a5bd3be5c9782c.mp3	enthroning_silence	unnamed_quintessence_of_grimne	['black_metal']
# std_4f68d3cba9266f9b14e564dc08cf55c8.mp3	salvage_whatã¢â¬â¢s_left	suicide_in_the_eyes	['metal', 'experimental', 'thrash']
# std_4f75fd75b0a92dbfc33cb0e6e091baec.mp3	drautran	der_erste_nachtfrost	['black_metal']
# std_4fe6bf6b246f1758da45861a1667aa34.mp3	in_somnia	killing_in_the_name_ratm_cover	['metal', 'hardcore', 'alternative']
# std_5051c77c5cd709790f7cf92119bb3e02.mp3	haunted_life!	5_problem_to_a_50_solution	['hardcore', 'punk']
# std_51c65aef6b8c61ba947bd131c4a8eb92.mp3	theudho	awakening_of_the_emperor	['metal', 'black_metal', 'thrash']
# std_52bd7fff5dd45b5586978cd91e538eba.mp3	edenbridge	shadowplay	['metal', 'rock', 'gothic']
# std_52c93ce8538d08cdb312292ac9b386fa.mp3	rickets_madcore	iguana_fits	['metal', 'hardcore', 'jazz']
# std_5301f8f4fe4d420c7872cd64d46e1f8e.mp3	threads	the_emperor's_new_clothes	['metal', 'powerpop', 'rock']
# std_5374b3416348b2ef09cb823840e532b1.mp3	carpathian_forest	a_world_of_bones	['black_metal']
# std_541b8c43d069c4d9da7596f78399c1cd.mp3	the_blackest_grey_&quot;recording_promo_2008&quot;	arranging_self	['hardcore', 'death_metal', 'thrash']
# std_5431229d6775981e52418bd4b10a8b19.mp3	rumble_militia	solution	['metal', 'hardcore', 'punk']
# std_5541631c4e3023394e38db20126adaa7.mp3	sanctuary	long_since_dark	['metal', 'metal', 'metal']
# std_567d2589274a67201da902733fe41f4f.mp3	korozija_metalla	v_storme_viking_i_mech	['thrash']
# std_5687b7ee5456b90e869e4f9744e3ba51.mp3	soul_takers	tides	['metal']
# std_56c66bb484cb28a66eb2854dcc0b52d7.mp3	prevail_within	kill_the_lights	['hardcore', 'rock', 'punk']
# std_5725ce7fc6bdeca2eef418d09a24847b.mp3	decemberance_(in_search_of_label...)	time_pt2_2006	['death_metal', 'experimental', 'down-tempo']
# std_5736b9449b381578499fca978774279b.mp3	k1-2b	drone	['metal', 'experimental', 'lounge']
# std_5753e09b16e75b87c1f42c7f0a1ed98d.mp3	havochate	cold_embrace	['metal', 'rock', 'thrash']
# std_577cad27309a50c635c30e6df042173a.mp3	out_of_body(album_is_being_delayed)	city_of_angels	['metal', 'hardcore', 'progressive']
# std_57a84b1aafff009dc568bbff7b12db55.mp3	growing_concern	misconceptions_of_pride	['hardcore', 'punk']
# std_5801496fa70b74fcdd9255124428faf6.mp3	richard_powell_&_banda_official	grafton_house	['metal', 'classic_rock', 'rock']
# std_587f0594347e6d83a29cd923f53097e2.mp3	antitoxina	aguacate	['hardcore', 'punk']
# std_58f77148a563873619c940db22e20a4e.mp3	stygma_iv	stigmata_iv_fever_dream	['metal', 'progressive']
# std_590a32582a5743fdc6420c96e4b7d5cd.mp3	loch_vostok	gestalt	['metal', 'progressive']
# std_597535f6c506ae52880bd05b8914a50d.mp3	crash_box	nato_per_essere_veloce	['hardcore', 'punk']
# std_5a33ecb4ec369d8bfbf571684af17e23.mp3	pitbull_daycare	you_can't_fight_it	['metal', 'punk', 'industrial']
# std_5ac56e851d41fa17e58f680a3c5e6f96.mp3	catharsis	bow_down	['hardcore']
# std_5affcdd6670b14dda7afee5ca2a2342e.mp3	drug_free_america	heaven_aint_high_enough	['metal', 'electronica', 'industrial']
# std_5b38960c6cd70710f0dbe08b7d2fa775.mp3	of_sound_and_fury__(on_tour_now!!!)	chaos	['hardcore', 'christian']
# std_5d1cb7d810ca047b5fe77e0d483137e0.mp3	gerty_farish	the_friendliest_dog_in_the_who	['hardcore']
# std_5d59cffc82a20546475e8bf0e1772d57.mp3	diabolus_(looking_for_a_drummer!)	infernal_trial	['metal']
# std_5de4c6298e3db1eff31919acee7e04e5.mp3	hated_youth	hardcore_rules	['hardcore', 'punk']
# std_6051459be6d526af88025df1acda06c9.mp3	7_angels_7_plagues	the_commentators_despair	['hardcore', 'progressive']
# std_60d39bb82ce96312a87b3937e9e16259.mp3	andaja	rudens_raudoje	['metal']
# std_60f902cda92c5e9f39626d683a560676.mp3	tears_of_kali	obsessed_with_an_idea	['metal', 'death_metal', 'black_metal']
# std_6107bc5209e4b1fea653316a0fa16eb1.mp3	jeannie_dee	wonderful_messy_world__full	['metal', 'electro', 'comedy']
# std_617ee5e8a0ad8dc5677ce205fd231cff.mp3	pigmy_love_circus	murderer	['metal', 'rock', 'punk']
# std_61a84ee5232cbf6f4b8360f163fda5a3.mp3	tracy_gang_pussy	heartbroken_heartbreaker	['metal', 'rock', 'punk']
# std_6216feaee1ed96b6dcfe313bffbcdeb7.mp3	black_army_jacket	socm	['grindcore', 'hardcore', 'thrash']
# std_622932358967637e0dffb944a298c408.mp3	imperceptible_fragment	drowned_in_the_dark	['death_metal']
# std_6274afd9eadd34fa3fd6d700de32c84a.mp3	rise_over_run	confined_within_disease	['thrash']
# std_62a1a11f2c858c00653c5e8870a79678.mp3	..::bender::.proximo_disco	caer	['metal', 'alternative', 'nu-jazz']
# std_62b7bc55f2412a44f1ea9e0107d07d4d.mp3	nuestros_derechos	devils_repent	['metal', 'hardcore', 'thrash']
# std_631a545649176a7320967478a45d5eb5.mp3	rottrevore	disembodied	['grindcore', 'death_metal']
# std_638bd1577ad5cb47039c057f670b9c2f.mp3	sargeist	returning_to_misery_andcomfort	['black_metal']
# std_644703d447387526d981ba237ff9941a.mp3	xiron	immortal_light	['metal', 'progressive', 'thrash']
# std_64ddeb412bd41d97b07f0d3106483ed0.mp3	for_selena_and_sin	million__miles_high	['metal', 'pop', 'gothic']
# std_65829c50ee352b16b4649eb6455e1e4c.mp3	mastabah	arterial______________excerpt	['metal', 'grindcore', 'death_metal']
# std_65aabe18865e90cf1fde249652c942e8.mp3	putridity_-_m.o.d._pics_up!!!!	conscious_in_rigor_mortis	['death_metal']
# std_67f177b7cb7a582e69dd6c3166df7e9a.mp3	wrtx	death_is_common	['metal', 'thrash']
# std_685cb5ecbc20e3ca2bdaab27399b8ffd.mp3	evereve	pine_oil_heaven	['metal', 'gothic']
# std_69bf7e6174779e351ba9f8fdea453a2f.mp3	jen_lasher	kiss_the_sunaaren_san_remix	['screamo', 'acoustic', 'bluegrass']
# std_69e875a38ffdffc8865249febd20d557.mp3	surgical_steel_thx_everyone_for_a_great_reunion!	moby_dick	['metal', 'rock']
# std_6ad0568c6137a205f63e26e147073252.mp3	safe_harbors	the_escape	['hardcore', 'punk']
# std_6aea17de9df8dfcb7b478123fd2beccf.mp3	choukoku_no_niwa	fukurou_01	['hardcore']
# std_6af29f8388eb9aaa25b31a2adc17a46b.mp3	warface	judgment_defiles	['metal', 'death_metal', 'healing_&_easylistening']
# std_6b708b956adbb451787f4dc1cd988deb.mp3	aurelia	silhouettes_of_shipwrecks...	['hardcore', 'punk', 'italian_pop']
# std_6b7a1b8d464e4be2a46495d56aae24f2.mp3	kundalini_rising	hypoxia	['hardcore', 'electronica', 'alternative']
# std_6c76f2beb31e2c1ca15d0e6622f1b537.mp3	funeralium	nearly_the_end	['metal', 'down-tempo', 'progressive']
# std_6d33041666024703e73469b374e49baa.mp3	leather_nun_america	urban_plight	['metal', 'metal', 'concrete']
# std_6ddc9f02b441807eb8f9a49e870b81cf.mp3	john_neff	new_track_7	['happy_hardcore', 'hard_house', 'idol']
# std_6ded857efeb468050ee92cddb410efb0.mp3	hardstyle_mafia	takin_over	['hardcore', 'hard_house']
# std_6e49759cff5f1068165d4bf0a3c3ee9a.mp3	holy_rollers	grey_walls	['hardcore', 'punk', 'thrash']
# std_6e613f281c96ce0a939f2e91a1350405.mp3	big_cockã¢ââ¢_-_the_hardest_band_in_the_landã¢ââ¢	king_of_cool	['metal', 'classic_rock', 'rock']
# std_6e7cd5291721b8c8340528d14f421b44.mp3	necrocest	persistant_genital_warts	['metal', 'grindcore', 'death_metal']
# std_6f044b8ffc9b7de54ceef1a61d80ad08.mp3	district_9	think_about_it	['hardcore']
# std_6fab68753bb2812ce55eeeb30f3a9a18.mp3	pitfiend	intro	['metal']
# std_7048f8a1bbb66f22a21b4f77f3502339.mp3	make_or_break	get_outta_town	['hardcore', 'punk']
# std_7061b3b4475bb3930629ed63eae26da2.mp3	eradicate_new_album_!	clos	['metal', 'thrash', 'industrial']
# std_70a8908df17941da1fd715d4a8985129.mp3	nightstick_justice	paranoid	['hardcore', 'punk']
# std_70b24c8a6f002dde89087693e17098cd.mp3	lost_in_tears	circle_of_despair_demo	['metal']
# std_710121d14c379143a6ed589c5e298ef8.mp3	fireign	soldiers_of_war	['metal', 'thrash']
# std_718dc6290b8158fd56d3d361fa9da4d4.mp3	willow_wisp?(rip_traci-a_true_drum_god!)	sodomized_by_god	['metal', 'black_metal', 'gothic']
# std_724edbce7241bf6570a2a0dc469b563c.mp3	bones_brigade	skate_or_die	['hardcore', 'punk', 'thrash']
# std_72c48127e8552349a009f18159afbb87.mp3	rosa_tattooada	nao_pode_ser_voce	['hardcore', 'classic_rock', 'rock']
# std_72f7dad87145a72a022e511711f59f6e.mp3	wretched_asylum	wrapped_in_sheets_of_blood	['metal', 'industrial']
# std_73af22c247d50c6653ab7efd9d364a1e.mp3	slow_roosevelt	cake	['metal', 'alternative']
# std_73cb7ecd6fe63ff674eee8f68e578f89.mp3	ninnghizhidda	moonlight_serenade	['metal']
# std_743ed8ae0cfeb44a513706cc74e8866f.mp3	prymary_(new_album_out_in_&rsquo;08)	oceans_of_insolence	['metal', 'rock', 'progressive']
# std_7521535038f9ea16eb2f268dc0d0c65a.mp3	red_aim	my_lovely_mr_singingclub	['metal', 'rock']
# std_75839ef916db474cef2582b34db7d303.mp3	sixes_&_sevens	the_bleeding	['metal', 'rock', 'progressive']
# std_76005b5e24933b64a5a141996d881d14.mp3	operating_table	autopsy	['death_metal']
# std_77c422f86df929bbd5db342aefad18a1.mp3	cusp	lifesource	['metal', 'thrash']
# std_782a9ff8279fc277c0813b6ac53ab7ac.mp3	flatbacker	avalanche	['metal']
# std_79365f8405bef61659364d7220432607.mp3	colossus_of_rhodes_(is_back_in_the_lbk!)	the_probability_of_a_promise	['metal', 'screamo', 'rock']
# std_794794703a9b9ca633e340a7e639584e.mp3	the_grannies	don't_step_on_my_tits	['metal', 'garage', 'punk']
# std_7a0ec5dd15c91461d5ea05ac7aea7fe9.mp3	exorcist	black_mass	['metal', 'metal', 'metal']
# std_7a308c877c72a877894917f4178da0ef.mp3	dark_lunacy	fragile_caress	['metal', 'death_metal', 'progressive']
# std_7bb9ab274675e82a1bafcae4608de961.mp3	daedeloth	waiting_for_the_wind	['metal', 'death_metal']
# std_7c10a09fff1ba4a7e838643513e4f8d7.mp3	wichita_falls	road_of_sorrow	['metal', 'hardcore', 'progressive']
# std_7c302f1c282c06f38e86eb73f4ca3937.mp3	insanity_(auditioning_bassists)	mortification	['metal', 'death_metal', 'thrash']
# std_7c4bdb3993d3568cc29adc5dc36d0dc7.mp3	project_hopeless	du_har_blod_pa_dina_hander	['hardcore', 'punk']
# std_7d064264c7ed6a1ccfd068bd3404994e.mp3	premature_burial	masquerading_as_the_almighty	['metal', 'grindcore', 'death_metal']
# std_7d38b37f54d04fa4c1fd27ba293faf53.mp3	sphere_of_souls	until_death_do_us_part	['metal', 'rock', 'progressive']
# std_7e1bd0387a012df21e2cc493c3c94305.mp3	engelsblut	wanker	['metal', 'gothic', 'folk_rock']
# std_7ed1eb8cc149978441ae02d6b3f2b454.mp3	septembre	into_all_shapes	['metal', 'rock', 'alternative']
# std_7f34248dc4200b5ed0d1d3b826dde4b4.mp3	morifade	ending_of_time	['metal']
# std_7fc5b7675ba92913f1705d1ff621fbf3.mp3	divine_decay	through_my_eye	['metal', 'thrash']
# std_804dfc5927566c9cbbbdf97f3ff1e238.mp3	rifu	sold_out_world	['hardcore', 'rock', 'punk']
# std_8054c710b8bdb398f506c440ba15ff63.mp3	maul_halten	pc	['hardcore', 'rock', 'punk']
# std_8100f571c021847e858e261ada270b4f.mp3	slow_grind	the_challenge	['metal', 'death_metal', 'thrash']
# std_81047621bbb8b292196b94ac4db16358.mp3	triumphator	infernal_divinity	['black_metal']
# std_810aa25254ea0634e8e16bc88287a9b2.mp3	lv-42666	hey_dont_ask_me_man	['grindcore', 'death_metal', 'gothic']
# std_81194e95f07ff0377561273ad04ee9b3.mp3	bulldoze	respect_through_fear	['hardcore', 'hardcore', 'hardcore']
# std_8212d5193c0824cf46fc81300a671e4b.mp3	law_of_the_vital_few_(new_songs!)	harbinger_of_cataclysm	['metal', 'death_metal', 'progressive']
# std_829eb7fdc09f1ac3fcbbc49deaeeed6c.mp3	choke_puppy	one_by_one	['hardcore', 'punk', 'ska']
# std_82e94d52404255ad519c0bdf1f7eddd8.mp3	catafalc	small_world	['death_metal']
# std_834d9e8c0ed23450dd8ed890c26a8680.mp3	marian_gold	forever_youngh	['hardcore']
# std_838512da4aaeb18c7fdd7508a854f3c3.mp3	overbass	le_petit_cactus	['hardcore', 'punk', 'thrash']
# std_8432f2cd259b96b614f68d7636622268.mp3	vext_intent	hell_2_pay	['metal', 'rock', 'funk']
# std_84b5172165b8e7d302e9027ade3a88f8.mp3	trance_of_mine	awakening	['metal', 'rock', 'alternative']
# std_84c6dbaaef743cc5a3a14c4df7a9ddfe.mp3	castortroy	worthless	['metal', 'rock', 'alternative']
# std_85648792392f4bbb32a968964f6d12b4.mp3	evil_beaver(evie_evil_8/28_at_the_stone_hollywood)	honey_pump	['metal', 'experimental', 'punk']
# std_8668e6b20fe579f66cea443418071406.mp3	level_above_human_(live_pics_online!)	hypnotic_spasm	['grindcore', 'death_metal']
# std_874da786fc32929a14296bfd9550330b.mp3	dxm_is_now_mtm	the_virus	['metal', 'hardcore', 'death_metal']
# std_875ef4c9ebde23d1e072b18bd7441a2d.mp3	agent_zero	tire_fire_extended_mix	['metal', 'rock', 'reggae']
# std_880aa8ff42b8f0a52bb27e1cc72e941d.mp3	gantz	vastakohtia	['metal', 'rock', 'alternative']
# std_8821d641f8970501f3873cfdfabc912d.mp3	curriculum_mortis	into_death	['death_metal']
# std_8822d38e794fb2fa3be369bffd34a4a6.mp3	downshift	vicious_circle	['metal']
# std_885fa7d5386ed103fa458da026a7343d.mp3	cemetery_of_scream	komatrance	['metal', 'rock', 'gothic']
# std_88973efdd16dafb9ad5ad90141b69efd.mp3	meccano_twins	dominhated	['hardcore', 'industrial', 'idm']
# std_88a031122df9833a0136f45ccf272b03.mp3	andy_winter	shades_of_light	['metal', 'progressive', 'classical']
# std_88bff60a6253bf2dfb7ea272aba7bcc6.mp3	nachtfalke_(official)	vallhalla	['metal']
# std_88d0d1978a38a858759356ec1af1d116.mp3	anterrabae::check_the_remix::	pink_and_tender	['metal', 'hardcore', 'rock']
# std_88d0da906638e3998463fdb88559084e.mp3	heaven_&_hell	heaven_and_hell	['metal']
# std_88d3c3dce0598f560d7eb8cc7c7a4d45.mp3	lipstick	nanana	['hardcore', 'rock', 'alternative']
# std_894e4c7153515968613992cddb1bfe3f.mp3	family_values_tour	atreyu_ex's_and_oh's	['hardcore', 'rock', 'progressive']
# std_8a03089d59979054dd973a6ae88cd9e1.mp3	vverevvolf_grehv	over_active_appreciation	['death_metal', 'experimental', 'electronica']
# std_8a077ca7c46c1f8cadf9b58130077f5d.mp3	sinisstar	psycho_sexy	['metal', 'rock', 'industrial']
# std_8a503b79d6a6f385608c657d13e24ff1.mp3	the_chinese_express...isn&rsquo;t_dead	said_the_father_to_the_son	['metal', 'rock']
# std_8ad0ba6faf160e79397295413f0477b9.mp3	heavy_rocker	korn__yall_want_a_single	['metal']
# std_8ad914d9314f527205a67d7950c295b9.mp3	running_wild	uaschitschun	['metal', 'rock']
# std_8afe319c78f5427c929e549a7d3e44fa.mp3	zeroed_out	plantsville_rock_village	['metal', 'punk']
# std_8b03ca26e6273f7fc212cc476eab70ad.mp3	gorath	sagittarius	['black_metal']
# std_8bfaedd5e80a018919133a21a4063248.mp3	warcrimes	hands_of_oppressors	['death_metal', 'punk', 'thrash']
# std_8e49e4d25f0d75650b19898d7a338b5d.mp3	dread_cannibals	perfect_people	['hardcore', 'punk', 'ska']
# std_8f0021b776965e7b4a5fa1ed951a3cf0.mp3	obscurant	face_in_the_mirror	['metal']
# std_8f7e927b34b0e130370bb9cdc3a66466.mp3	intense_degree	victim_of_pain	['hardcore', 'punk']
# std_8fcbdf7644e7381bc477add0b20fe0ef.mp3	death_dies	death_dies	['black_metal']
# std_8fdac7e2a0f2d4594cf53e0c984d0750.mp3	the_carburetors	whole_town_is_shakin	['metal', 'rock', 'punk']
# std_9010661f455eb0114c8e92eb3685814c.mp3	crimson_lotus	velvet_night	['metal', 'progressive']
# std_90ab0bdcb037b2bc00013a5273122019.mp3	eyeless_writing_new_album	sample_of_yesterday	['metal', 'metal', 'metal']
# std_914174babf5deb8e6a5864bf99f525a8.mp3	conspiracy_a.d._new_blog_up!	the_greatest_trick	['hardcore', 'death_metal', 'thrash']
# std_917ec4555a4bc01737b3a55c91b6c108.mp3	ethan_novak	asshole	['metal', 'rock', 'shoegaze']
# std_917f65770982d9d3640e7a3d9765e864.mp3	length_of_time	love_your_enemies	['metal', 'hardcore']
# std_91942f0d7bd2b5d857045df6b4e9678a.mp3	mechanical_chaos	sounds_from_a_dying_planet	['metal', 'death_metal', 'thrash']
# std_939c5c02675a53143e1b23357ff8c2c0.mp3	no_trigger_(merch_store_wide_open)	bust_tropical_new	['hardcore', 'punk']
# std_93a6301269ac69c5295739a58fed4148.mp3	hezzakya	soul_collector	['metal', 'rock', 'southern_rock']
# std_94a27d13db797e4f8af3ae355f027307.mp3	scorngrain	ubermensch	['death_metal', 'thrash', 'industrial']
# std_9566f725bc6b585ad8202886ac317597.mp3	otophobia	hungry_hungry_hippocrites	['grindcore', 'hardcore']
# std_95fdac7bb30ddd90952bc255685329ee.mp3	penetrate	farewell_reason	['metal', 'rock', 'thrash']
# std_96c752e69debd3402f44b24b77f8dbae.mp3	cretin	daddys_little_girl	['metal']
# std_9724913444732b08fe05e654614c8640.mp3	arc_of_descent_check_us_out!!	forever_changed	['metal', 'hardcore', 'progressive']
# std_979b4d76b362d0e264153fef80fd5604.mp3	kodiak_bear_regiment	goat_and_gazelle	['metal', 'screamo', 'death_metal']
# std_9801ba57561615b480097a8b806978c0.mp3	absolute_defiance	maggot_infestator	['death_metal', 'death_metal', 'thrash']
# std_9801df7d90d3781078ddcdf99beccc50.mp3	john_neff	track_two	['happy_hardcore', 'hard_house', 'idol']
# std_9810bfc002e424e3dce5e5a7f6bcbe61.mp3	sweet_cheater	summer	['metal', 'classic_rock', 'rock']
# std_98747897d30eae3cca84d0c4b0f09219.mp3	amon_amarth_-_new_song_up!	pursuit_of_vikings	['death_metal']
# std_9899c3416b228b8a81ab61fef1b69137.mp3	less_than_jake	summon_monsters	['metal', 'punk', 'ska']
# std_98d846cb3cd7e4119c73b9f9df1f4c59.mp3	hanover_saints	writing_on_the_wall	['hardcore', 'rock', 'punk']
# std_99041a7fd7c25df4f0783e82e0521d98.mp3	masters_of_horror	2cents__the_afterlife	['metal', 'hardcore', 'industrial']
# std_9907522f5674ac23dd34655cd85229b8.mp3	vanna_(fall_tour_posted!!)	a_dead_language	['metal', 'rock', 'punk']
# std_990fa770de66ff8e7f361f5bbb2575b7.mp3	the_disappointments	sarah	['screamo', 'punk', 'ska']
# std_9980974744e25ad134ce90dc70405d40.mp3	night_people_productions	the_valley	['hardcore', 'experimental', 'blues']
# std_99dbbc3fdf57c9e4e7f6fc77324e5d25.mp3	asena	yamuk_prenses_ve_kedi_cuceler	['metal', 'rock']
# std_9b5adfcebe01fca066028021b9a6f404.mp3	braindead	guilt_and_shame	['hardcore', 'punk']
# std_9b8a6996395ab80ced24dad9016a0704.mp3	knochenbruch_(suche_drummer!!!)	sodomie	['death_metal', 'black_metal', 'gothic']
# std_9d0dd086b3e9d4943315ae8f062aa92a.mp3	deformity	drink	['grindcore', 'death_metal', 'punk']
# std_9deee7d09f3279b99e27edcf79371056.mp3	penile_suffocation	coprophaggot_spermanizer	['metal', 'grindcore', 'death_metal']
# std_9e8856b06f00e88a4c5899ce2fe5860c.mp3	termoil	don't_fear_the_reaper	['metal']
# std_9f6b1c4e04f4ffd886cd9510369ff90c.mp3	smogus	time_out	['metal', 'rock', 'alternative']
# std_9f78b6fe82724cc0232489e56233acee.mp3	neoplasmah	the_dome_of_electric_karma	['death_metal']
# std_9fd5e40d39320b315d0daf5daf03bfa7.mp3	neuropolitique	what_have_they_done_for_me	['hardcore', 'hardcore', 'punk']
# std_a0f74b72ee32c5cce080225f65de4584.mp3	deathtiny	heaven_and_lies_edit	['metal', 'death_metal', 'progressive']
# std_a1b5edde6d0df38abb83141afcc067f0.mp3	clownsack	the_box	['hardcore', 'rock', 'funk']
# std_a2d95e73558c206afebef474f71783be.mp3	hell_militia	torture_of_the_saints	['black_metal']
# std_a32c95d85dda871a796b55aaf4d99207.mp3	dispatched	terrorizer	['metal', 'death_metal', 'black_metal']
# std_a47b7110a52348488fd0346416d18fe8.mp3	arkitech	alanamra_remix	['hardcore', 'hard_house']
# std_a47b8d9dc19267aacd463e24eda5b723.mp3	gray_lines_of_perfection_[needs_a_new_guitarist!]	on_the_last_day	['hardcore', 'progressive', 'christian']
# std_a4d36dcb35f549b2f699502fc66e1ac1.mp3	union_of_uranus	circumstance	['metal', 'hardcore', 'punk']
# std_a65b1056f5c7db23da2999b04da598fb.mp3	chaostar	playground_adagio	['metal', 'ambient', 'classical_-_opera_and_vocal']
# std_a6dee53f2bf8c1d539f104b8833a2a1c.mp3	ultra_vomit_(nouvel_album_dispo!!!!)	quand_jetais_petit	['metal', 'rock', 'comedy']
# std_a708b8acd0da22f28bb36780da3c52a7.mp3	lawnmower_deth	feet_cleaner	['metal', 'comedy', 'thrash']
# std_a78ffeebff94c363dd086a50c9dc3e11.mp3	mercury_rain	eldritch_mirror	['metal', 'classical', 'gothic']
# std_a8a71db1b073f78236f0543b0a3a5cff.mp3	mayhem	funeral_fog	['metal', 'black_metal']
# std_a8cfb02158d2fd83fffd79ad13177c67.mp3	1134	insanity____new	['metal', 'metal', 'metal']
# std_a8fcb25ad38bf31c3acf1b7bf7614ce7.mp3	shape_of_despair	curse_life	['metal', 'down-tempo', 'gothic']
# std_a914b2ab7ddc745d1749ec2ec22a0c24.mp3	bombensturm	wir_setzen_die_segel	['metal']
# std_a95639b12a0afebd3a6d6f643732a43c.mp3	chauchat	archives_and_altars	['screamo', 'acoustic', 'shoegaze']
# std_a97215b514245f04843ab11a5167f485.mp3	heed	i_am_alive	['metal']
# std_a9dffa12376d0253f470527cf8806eb0.mp3	typozorg	ubel_katzchen_remix	['death_metal', 'experimental', 'industrial']
# std_aa4020caf73fdbec61dc8ca8d5ee518d.mp3	devotion_to_trust	a_call_for_change	['hardcore', 'rock', 'punk']
# std_aa493ec595cb104bf96298d0768d0b03.mp3	scumpies	die_nadel	['hardcore', 'rock', 'punk']
# std_aac496e82a3ea1e4d8b06f4c22fa8340.mp3	dead_emotions_[new_song_uploaded]	demon_seed	['metal', 'death_metal', 'thrash']
# std_ab471a35d7554ffec940d677b26c85bd.mp3	nohaydeaz	venus_against_our_decay	['screamo', 'rock', 'progressive']
# std_ab5d5530281510cdf223425a37b845e7.mp3	northwind	entropy_instrumental	['metal', 'death_metal', 'black_metal']
# std_ab8c2d8aac94ba21873caf8bad209462.mp3	jamey_jasta	hatebreed__to_the_threshold	['metal', 'hardcore', 'punk']
# std_abb9f654c923e4b94973b1e7ffc83b53.mp3	jason_viebrooks-bassist	mercy_is_no_virtue	['metal', 'rock', 'thrash']
# std_ac0a63ec63a41754be134651c79fc26e.mp3	hyimn	undone	['metal', 'punk', 'alternative']
# std_ac9d93ec83f1da3132221e83dac29e06.mp3	thy_infernal	the_hordes_of_satan	['metal', 'death_metal', 'black_metal']
# std_acdd21090d75ab225115e9d397151339.mp3	satariel	vengeance_is_hers	['metal', 'death_metal', 'progressive']
# std_ad36e2a82fdf044b2db9d94687098ae9.mp3	restless_youth	light_up_ahead	['hardcore', 'rock', 'punk']
# std_ad74383754928f82238cb030e0ceaf2c.mp3	mysteriarch	sovereignty_of_the_ancient	['black_metal', 'black_metal', 'black_metal']
# std_aec3e0b77e055df6237ce87f19f5e839.mp3	portobello_bones	el_negativo	['metal', 'hardcore', 'western_swing']
# std_af5c020c901cad4409971e798e89bc89.mp3	prophecy_of_doom	prophetic_believers_prepare	['grindcore']
# std_b081649e7bc7e9552e472d404a02fab1.mp3	xfilesx	wreck_yourself	['hardcore', 'punk', 'thrash']
# std_b14ea5601e0b0898b4ff5e5ab605bfc0.mp3	tracey_lamb	a_love_too_far_girlschool	['metal', 'rock', 'punk']
# std_b18ba73a666edcae0d45c5b521b6c71f.mp3	vii_gates	so_far_away	['metal', 'classic_rock', 'rock']
# std_b1d668aacfbd4ed729391ebb9e6ce85a.mp3	theory_in_practice_(two_new_songs_up)	departure	['metal', 'death_metal', 'progressive']
# std_b2ae0110aa8cf9cf6a3ce006acd4ab93.mp3	flesh_consumed_(album_out_now!!)	raw	['death_metal']
# std_b3066c9b4ba2258ba19811919fa37931.mp3	rock_goddess_from_hell	machine	['metal', 'rock', 'gothic']
# std_b38f03ca327d3e8c845ffea7846ebf70.mp3	suicidal_tendencies	facist_pig_live	['metal', 'hardcore', 'punk']
# std_b39d8421f9afa3ad62ff9ab8f0402884.mp3	the_reasoning	aching_hunger	['metal', 'rock', 'progressive']
# std_b3f702a8c84b7f2af288ee9de362f0ae.mp3	penile_suffocation	penile_vacation	['metal', 'grindcore', 'death_metal']
# std_b5bc5f1b548cd70f568cd3e1655a1657.mp3	lapis_lazuli	last_hour	['metal']
# std_b6414a8047b5fd82a8a3438e149caccb.mp3	prevail_within	god_save_the_scene	['hardcore', 'rock', 'punk']
# std_b6a41a2ac9c80bd791bfcc98e4102f25.mp3	herfst_-_new_songs!	shadow_and_dust	['death_metal', 'black_metal', 'thrash']
# std_b6ee5d5d78314018b7a93c7eea481ad6.mp3	bird_of_ill_omen	now_ruin_is	['metal', 'hardcore', 'death_metal']
# std_b767e5fdca3859260c6c81cfa38286f2.mp3	inhumate_(in_studio)	the_fight	['grindcore', 'death_metal']
# std_b7944a0b2e12f5fec689859bb4bd3578.mp3	conception	a_million_gods	['metal', 'rock', 'progressive']
# std_b79858d302ba5e032fc61ac90b326078.mp3	dead_hearts_(last_show_ever_september_12th)	hope	['hardcore', 'hardcore', 'punk']
# std_b86ee23ee9b8e510835ea9569d2d0ffa.mp3	epoch_of_unlight	the_highgate	['metal', 'death_metal', 'black_metal']
# std_b950ddc10a4c3569a29a57253bb3a883.mp3	gungnir	aurora_borealis	['black_metal', 'black_metal', 'black_metal']
# std_b9bc42b10f247b68104e9b2a67cff8d4.mp3	barricades	against_such_things_there_is	['metal', 'hardcore', 'christian']
# std_b9e614d98445ceb73ab8585c58bb6372.mp3	hezzakya	in_her_garden	['metal', 'rock', 'southern_rock']
# std_ba62a6807e1d0fad7041ec9b4774c8fe.mp3	abominator	activate_the_anarchus	['death_metal', 'black_metal', 'thrash']
# std_ba80b80892d82371fed672c91cb3dd47.mp3	terminally_your_aborted_ghost_(r.i.p.)	open_concave_chest_wounds	['grindcore', 'hardcore', 'death_metal']
# std_bacccc7541dea7dac64ce07e8c0c23ff.mp3	lahannya	bleed_for_me	['metal', 'gothic', 'industrial']
# std_bb33d1c38cc4485ee99540c8cbdb3259.mp3	back_when	soothsayer	['metal', 'experimental', 'gothic']
# std_bcbbf64300876f6d28a5d724362e9737.mp3	disbelief	when_silence_is_broken	['metal', 'death_metal']
# std_bcc49f689816780f38ac72d638d0f355.mp3	the_uprise	road_warriors_new	['hardcore', 'rock', 'punk']
# std_bd0ea2cef14e5532a823b3a16a3a1a5c.mp3	the_fad	vinyl_paradise	['hardcore', 'punk', 'ska']
# std_bd4139c895b72105733c08908629aae5.mp3	veloce_hystoria	medley_premastering	['metal', 'metal', 'progressive']
# std_bd586fe3763bb4f98fbc8383d76fd8f2.mp3	manimal._reprend_du_service_!!!	the_dark_half	['metal']
# std_bd5fe743f7bdc587598438ce65930b21.mp3	watch_them_die	bastard_son	['hardcore', 'death_metal', 'thrash']
# std_bdf14872a70ecb45443605d1c8c39517.mp3	denise_dufort_/_girlschool	mad_sister	['metal', 'rock', 'punk']
# std_be007ca395029605e374c2b608bb900a.mp3	5000_r.p.m_(encerradxs_componiendo_nuevos_temas)	ella	['hardcore', 'experimental', 'ambient']
# std_be7b9c7ec88d0adfd0ddecba9680c872.mp3	halo_of_flies_records	protestant_the_hate_the_hollow	['grindcore', 'hardcore', 'punk']
# std_be9331592ec307e72d4e5ef9c3715e6f.mp3	sinners_bleed_-_searching_for_a_label	ludo_game	['metal', 'death_metal', 'thrash']
# std_beb45acab92a46cac487f62ffa0fc565.mp3	kyle_snyder_the_music	turn_the_key	['metal', 'experimental', 'ambient']
# std_bfc499596162ed260f092764441d2593.mp3	ethereal_pandemonium	was_lost_and_now_i_am_sound	['metal', 'ambient', 'folk']
# std_c0098acede89c04851d716173914c9aa.mp3	bartholomeus_night	master_of_dread	['black_metal', 'black_metal', 'black_metal']
# std_c02552a16eb9f6bcfcd8a263056e8b66.mp3	the_outside_agency	the_neutralizing_agent	['hardcore', 'progressive', 'industrial']
# std_c0518a7137546b023474d2dbe144e8ad.mp3	dungortheb_(searching_dates_!!!)	silence	['metal', 'death_metal']
# std_c0878c4c03e671ad4e219c6cb7321e67.mp3	rwake	leviticus	['black_metal', 'progressive', 'southern_rock']
# std_c0b9c3db41e1789e62e04ee9109e8f47.mp3	alamogordo	mother_earth	['metal', 'hardcore', 'death_metal']
# std_c13879e89e01a21d19d9549fedfbbd25.mp3	i_scream_records	bad_luck_charms	['hardcore', 'rock', 'punk']
# std_c16445eea1d0650a812fea82b6190aa2.mp3	potential_threat_sf.	day_of_infamy	['thrash']
# std_c1780078bf8e5beef4fe40e8f8c92c2f.mp3	temple_of_baal	flames_of_baal	['death_metal', 'black_metal', 'thrash']
# std_c1afaf683a4db9b005733e573ecd9d2c.mp3	padmasana	the_ballad_of_the_geek	['metal', 'freestyle', 'experimental']
# std_c21dbaff28fa7afc56e930edfabdf5f8.mp3	daysend	born_is_the_enemy	['metal', 'thrash']
# std_c2288745e7ebf65295a67c6352ada14e.mp3	fgc	cut_from_the_fgc	['hardcore', 'punk']
# std_c2379fd12a4f537a1c4c46e21a527750.mp3	emerald_sun	sword_of_light	['metal']
# std_c3642b5e52c3a19e58100e289a28937c.mp3	lori_linstruth	dream_sequencer	['metal', 'rock', 'progressive']
# std_c3aeea7d0edf7a8b6e7c1e4cf4be4d27.mp3	nostrilsaurus	happiness_hotel_muppet's	['black_metal', 'punk', 'ska']
# std_c4067e8110390c6fe08976908a98b8a6.mp3	devil_in_the_kitchen	heather's_concussion	['metal', 'bluegrass', 'folk_rock']
# std_c473ee3119086ac4e306b37bdcf3c4a3.mp3	b.b.l.music_-_booking_-_promo	kang__real_hc_smell	['hardcore', 'punk', 'ska']
# std_c4fdbac0904265e8132de7abff6f4753.mp3	ancestory	petrol_pump_attendant	['metal', 'progressive', 'thrash']
# std_c54468ad203238f782f0601705304c33.mp3	bystander	careless_being_serious	['metal', 'rock', 'alternative']
# std_c54f95793a404578ef66a3cc6251f2c5.mp3	mental_care_foundation	corruption	['metal', 'rock', 'thrash']
# std_c5a7d473dcd454799d01a3970d63eb40.mp3	genosha_recordings	manhunt_2	['hardcore', 'experimental', 'progressive']
# std_c6c4a8e48cdd0c41b7102f4270b5ff87.mp3	dead_on_broadway	breathe_and_speak_easy	['screamo', 'rock', 'alternative']
# std_c6ccf1eff4a80c4c1ac11c9e0306086e.mp3	order_of_nine	a_means_to_know_end_medley	['metal', 'progressive']
# std_c7e74d32ec6b2453e8134ecf6ce744be.mp3	highlander	you_can't_make_me	['metal']
# std_c94d2346ca5f7376edcab64777b19895.mp3	sweet_silence	stronger	['metal', 'death_metal', 'thrash']
# std_c9a37d2a0a0e0eedbe1479016afdf84d.mp3	right_brigade	plead_your_case	['hardcore']
# std_c9de494d58bf4e9bed552479bf44945a.mp3	katalepsy	gialo	['death_metal']
# std_ca2c0a5d3c4c4b8e49d475f78baacaf5.mp3	nine_volt_fist	revenge	['metal']
# std_ca4c6d01f3d8aeb9fcb1e967620af943.mp3	virgin_snatch_(in_studio)	trans_for_mansions	['thrash']
# std_ca7bf99655e3664ccd95613fa9247407.mp3	moderat_likvidation	sprangd	['hardcore', 'punk']
# std_ca9666422c74fffd32ffbb66e929fa6f.mp3	mirthkon	johnny_yen	['metal', 'experimental', 'jazz']
# std_cb01dba5a29779b09412cefb005e3943.mp3	the_lawyers_karma	domination	['metal', 'electronica', 'industrial']
# std_cb82f1061fc1ed1c14f3fb7b5ab1875c.mp3	decayed	spikes_leather_and_bullets	['metal', 'black_metal', 'thrash']
# std_cc39c1c4a1eb6162ef0af5cb82d235d1.mp3	vitriol_(final_show_tba!!!)	a_longing_for_home	['metal', 'death_metal', 'progressive']
# std_cc3aa96a36ba46962ab201def713ed3d.mp3	mandrake_(mary_celeste_out_now!!!)	adore	['metal', 'gothic']
# std_ccc6ec0365b23bfb3433a7de6e95c169.mp3	winterdome	haushoch_tuermten_sich	['metal', 'gothic', 'folk_rock']
# std_cd01d0fe6361f924458668c06e975a0f.mp3	gjenferdsel	thurs	['metal', 'folk', 'black_metal']
# std_cd05fb57b6e69e0cfb69cb5ba8c34a53.mp3	ruined_machines_(new_album_on_itunes!!!)	a_milestone_your_every_step	['metal', 'rock', 'progressive']
# std_cd89cef2867bdb2cdb5a1ea6b2437be6.mp3	mephiztophel	return_to_chaos	['metal', 'death_metal', 'black_metal']
# std_cd8d9f0c03db01c88be02d7af70b25ad.mp3	dakrya_(debut_album_out_now!!)	monumento_samples	['black_metal', 'gothic', 'classical_-_opera_and_vocal']
# std_ce12ffbf4eb32362f3143aafa9f89d95.mp3	krater____llibertat_total_pres.@.s.	epidermis	['metal', 'hardcore']
# std_ce7dfd8f90cba6e7457f25bcd04bcd75.mp3	stephen_tanner	beav	['death_metal', 'black_metal', 'hawaiian']
# std_cf84b67faefaa00c7a3ae2e002d95360.mp3	olemus	i_hate_myself_today	['metal', 'rock', 'industrial']
# std_cffc3b6d9c0707f14ce4a75149edd5ef.mp3	fastlane	sunset_at_seventeen	['metal', 'rock', 'pop']
# std_d0442f19fad0254d056ae600c246ed64.mp3	skew_siskin_-_official_page	my_generation	['metal', 'rock', 'punk']
# std_d065217919d038515270f4e713682beb.mp3	attitude_adjustment	my_problem_is	['metal', 'hardcore', 'thrash']
# std_d0ba00eae4391afdb5ea73e744e2588b.mp3	noisekick	oogkaspenetratie	['hardcore', 'hard_house', 'breakcore']
# std_d17122af2a798848a9e44d44f436b7aa.mp3	in_articulo_mortis	muerte_a_la_humanidad	['metal', 'death_metal', 'death_metal']
# std_d1f83acbbbdcb37c2a62f94a8c8aa268.mp3	graves_of_valor_(writing_new_music)	kiss_the_snake	['death_metal', 'death_metal', 'thrash']
# std_d2b4364466d55c09abc93af2a1bca06c.mp3	escape_to_everything	addiction	['metal', 'rock', 'alternative']
# std_d2fa403820b6b5e62072ba0a98dc3f61.mp3	fermento	messiah_to_burn	['death_metal']
# std_d2fda2e1f485a1c5890362c695b98daf.mp3	the_sawtooth_grin	boxcutter_facelift	['metal', 'hardcore', 'death_metal']
# std_d34a49b11fa5eadf6f8e5a974e0aa1ae.mp3	head-on_(have_split_up!)	sunrise	['metal', 'rock', 'southern_rock']
# std_d35af2c0635c37bb26be419ae5a7416e.mp3	bane_of_existence	cankerous	['death_metal']
# std_d42bf5ee6746fdd54ffbff4c2459b319.mp3	1000_homo_djs	better_ways	['metal', 'industrial']
# std_d510c68c661558282e651de50335eccd.mp3	nutmeg	got_some	['hardcore', 'rock', 'alternative']
# std_d5d28f457f76e5b255fdab63222a9999.mp3	damien_harrison	salvation_of_the_silent_planet	['metal', 'rock']
# std_d82c7a32375979592cb5ca9ec1b3adb1.mp3	ninebar	all_for_nothing	['hardcore', 'hardcore', 'hardcore']
# std_d840d8b1547109689aac28f410ecc2c5.mp3	outatime	outatime	['hardcore', 'thrash', 'surf']
# std_da20084dc84777724a7129189e4d7b50.mp3	bleed_the_sky	minion	['metal', 'metal', 'metal']
# std_db67f71e79659d31a0b923508db343be.mp3	bowels_out_[blasting_guttural_sickness]_nydm	decimating_the_decaying_orific	['death_metal', 'death_metal', 'death_metal']
# std_dc36a2dff67d7467bf62423014a433f2.mp3	doctor_nerve	trash	['metal', 'experimental', 'rock']
# std_dc4fb82062516157bebd34593ccc8ffe.mp3	dementia	tree_of_souls	['metal', 'metal', 'metal']
# std_dc783dcda8001df098880e5d2fc53323.mp3	tagada_jones	cargo	['hardcore', 'rock', 'punk']
# std_dcb876dfa197ea46e4203d257bbfb48a.mp3	wallmen	chuck_connors	['death_metal', 'melodramatic_popular_song', 'christian']
# std_dd84ecdf2af4023eacb9e794c6ba1cb0.mp3	one_eye_shut	everything_must_die	['metal', 'rock', 'blues']
# std_de16a927ad22ed1af0581a8befa52f3f.mp3	hegira_records	this_art_is_suicide	['metal', 'hardcore', 'death_metal']
# std_deb4f368e3f14726f36779a0d845feaa.mp3	amok	goatflesh_removal_ii	['death_metal', 'black_metal', 'industrial']
# std_dfbebabaa811ae87563d8bda49ba07bc.mp3	counteractive	no_regrets	['hardcore', 'rock', 'punk']
# std_dfcf4cf63c188207554755f859c12a41.mp3	dm3_productions_inc.	soul_kept_bearers	['metal', 'hardcore', 'death_metal']
# std_e036af4da630aa1eea365b4ac568b6ed.mp3	the_4_sivits	live_right_now_dont_give	['hardcore', 'punk']
# std_e099929590dfa1c0df2026fc76addbff.mp3	spiritual_beggars	killing_time	['metal', 'rock']
# std_e119f4defc394551a42bee634254b0d7.mp3	sunterra	somewhere	['metal', 'rock', 'gothic']
# std_e1eddcfb73f1e1c453e3ef02e6482a97.mp3	patrick_stevens_(music_page)	gliding	['metal', 'rock', 'progressive']
# std_e2e0302239206928abf784dd28640fe3.mp3	nfd	when_the_sun_dies	['metal', 'rock', 'gothic']
# std_e320fba34f1b070a8074574faa495132.mp3	oil_seed_rape	infant	['hardcore', 'alternative', 'industrial']
# std_e329b73a95702f60794f0e9aa49071dd.mp3	gun_kata	the_jealous_cryptozoologist	['grindcore']
# std_e34446fa171324396e0ce66a4b7f82d4.mp3	metharia	karma	['metal', 'rock', 'alternative']
# std_e379267ed5bf0e48a76261c40c129277.mp3	stand_aside_(2002-2006_dead)	raptures	['metal', 'death_metal']
# std_e3c2e515f304f63cb2e9ae9a5b043168.mp3	wow,_owls!	let's_get_the_fuck_out_of_racc	['screamo', 'hardcore', 'rock']
# std_e46b6864ae02da4593fac4ea7d7e08f3.mp3	xoliverreedx	oderint_dum_metuant	['grindcore', 'hardcore', 'punk']
# std_e5103b34bc2d4e923f614f282c2ffbbe.mp3	qadesh	alas_rotas	['screamo', 'hardcore', 'punk']
# std_e542488c7d0a44ab4d438ae83d521cd7.mp3	dhaubgurz	sample_on_wind's_wings	['black_metal']
# std_e5eefd4f8512fff227387136cf858098.mp3	infernal_majesty	death_of_heaven	['metal', 'death_metal', 'thrash']
# std_e66db805c6ac4ac227b627644431a756.mp3	chainbreaker	lebewohl_1	['hardcore', 'hardcore', 'punk']
# std_e750aa615bcc1284641174199288e50d.mp3	conditioned_response	stealin'	['metal', 'rock']
# std_e7d51dc9ed85561d7bfdfeb854dc2ad3.mp3	procton	seelenfest	['metal', 'death_metal', 'thrash']
# std_e80035ae64d15ad7633dc440c91f9254.mp3	thy_legacy	reverse_exorcism	['death_metal']
# std_e810abbb547f749d17d6683ec603687f.mp3	doug_doppler	starcrossed_lovers__2005	['metal', 'rock', 'progressive']
# std_e83cf420f9a3e30c5883333643967819.mp3	dr._acula_{buy_our_cd_today!_}	piano_lessons_can_be_murder	['grindcore', 'hardcore', 'death_metal']
# std_e85501230ac8b06db949550a6821d2d6.mp3	etwas_dein	blind	['metal', 'alternative', 'gothic']
# std_e9424a3d047910e43f3b31f9117f77ea.mp3	sonic_pulsar	sonic_pulsar	['metal', 'rock', 'progressive']
# std_e953207de0be2d5ebdecaeb7c22c844b.mp3	slaughterhouse_57	billy_mackenzie	['metal', 'punk', 'thrash']
# std_e98a09957b205efc1ca25d2ddda659d5.mp3	forbidden_forest	call_of_the_wild	['metal', 'death_metal', 'thrash']
# std_e9999ff6b91251c6abf271ababd6cc8b.mp3	existench	pointless	['grindcore', 'hardcore', 'thrash']
# std_ea2a4f51ec53f68f760513365b96762a.mp3	doktor_kosmos	dk_spelar_pa_tensta_torg	['happy_hardcore', 'pop', 'new_wave']
# std_ea8d3c2805c3b5525588ba2f76d181b3.mp3	schloss_tegal	cannibal_communion	['death_metal', 'experimental', 'industrial']
# std_ea8e480657e7ceeb17f4d08bfa10607b.mp3	hulk_blood_(new-ish_songs_up!)	as_life_is_crushed_into_ashes	['metal']
# std_eb05719cb6f9db617e5ebb958977baed.mp3	sepsism	sodomizing_the_exhumed	['metal', 'grindcore', 'death_metal']
# std_eba6fb7dfa23659e8fde4361b45b17ff.mp3	jurassic_jade_-new_song_up!!-	hemiplegia	['metal', 'hardcore', 'punk']
# std_ebd943f5397b5e7c1dc65fd78513df2c.mp3	schifosi	obliging_suicide	['metal', 'hardcore', 'punk']
# std_ec731465c0104a0e56e598c43c88f784.mp3	hb_surround_sound	wake_up	['metal', 'reggae', 'punk']
# std_ecc55b748c4e1a0df67ed952322301c2.mp3	sabrina_sabrok_music	quiero_ser_santa	['metal', 'punk']
# std_ed76ce1897b8d302e0505371f858a7b8.mp3	wretched_asylum	we_all_die	['metal', 'industrial']
# std_edcc5ad4f19d46145e278b71317733c2.mp3	gummi_bako	underground	['screamo', 'powerpop', 'country']
# std_efa53ba3772d43202c2aa68a623fddfa.mp3	mx-80_sound	i_walk_among_them	['metal', 'rock', 'new_wave']
# std_efd0109cedb1964c432a7eff0e567a67.mp3	taste_of_tears_[writing_new_songs]	architects_of_downfall	['metal', 'death_metal', 'progressive']
# std_efd4b417763cb55f886917bf125e3301.mp3	anabelle_lee_(is_done...rip_march_2008)	deathstar	['metal', 'screamo', 'rock']
# std_f101334874651a51259553b08d6c5c73.mp3	trigger_renegade	building_the_pyramids	['metal', 'rock']
# std_f10f40fc3e92b2ec72200d712fc7f09c.mp3	the_smackdown	taking_over_primetime	['hardcore']
# std_f11d77d51fdfe2579cd0b27263e2e9fa.mp3	laruso	this_isn't_a_moon_it's_a	['metal', 'hardcore', 'rock']
# std_f2b238f1420c865c9532e5deab5b9d72.mp3	manufactured_god	big_dicks_kill_chicks	['metal']
# std_f2ed72612d059f0c7f80d680cf9fc944.mp3	flynn(cornerstone_pics_up_)	show_and_tell_aint_til_thursd	['screamo', 'rock', 'christian']
# std_f429caca1f3fde4f8209eff0f305c3a3.mp3	vaporizer	mindkill	['hardcore', 'industrial']
# std_f442de2f528a1c7b40e38c3009ce3b88.mp3	undercroft	enemigo	['metal', 'death_metal', 'thrash']
# std_f4f051bf91d2766da9bc5c198a09411c.mp3	excruciate	beyond_the_circle	['death_metal']
# std_f6221498a2eb05d293988c018ba0dcef.mp3	hardstyle_mafia	stab_u_in_the_back	['hardcore', 'hard_house']
# std_f780622156dc2e763aa6c54c60763744.mp3	nunwhore_commando_666	consequence	['grindcore', 'electro', 'afro-beat']
# std_f7ee1af36044f69f0e0a73be2f0d8c48.mp3	la_quiete	cosa_sei_disposto_a_perdere	['screamo', 'hardcore', 'punk']
# std_f881cac9861a1880f152c8ffb780f78c.mp3	my_ruin	through_the_wound	['metal', 'rock', 'southern_rock']
# std_f88b214b530fb2374125d55028b57847.mp3	ligeia_-_bad_news_in_stores_now!	the_blackout	['metal', 'hardcore', 'pop_punk']
# std_f9d81552cb072e08cc4513addb044c32.mp3	chauchat	wound_of_discovery	['screamo', 'acoustic', 'shoegaze']
# std_f9f1d648a3973bc8bb2209247920fe90.mp3	rotten_penetration	double_anal_penetration_in	['grindcore', 'death_metal']
# std_faa69da8cd0e9688746a0e30ebcf0c1b.mp3	four_maniacs	here_we_are	['metal', 'hardcore', 'rock']
# std_fabdb76f975e788a9511c8924485c325.mp3	year_of_the_dragon	ride	['metal', 'punk', 'funk']
# std_fb064c47d0b4a769c89c82fcc9f1bf4c.mp3	negligent_collateral_collapse_(rip)	ncc_something_is_collapsed	['grindcore', 'grindcore', 'grindcore']
# std_fbee18f6846f637be2bd68be7777f239.mp3	cause_of_divorce	maggots_parasites_and_me	['metal', 'grindcore', 'punk']
# std_fd70480af4609cf7cf2c0e9d0336e45a.mp3	screechy_dan	brklynja_remix	['hardcore', 'reggae', 'reggae']
# std_fe204146d86ce4012849546f78a8c00a.mp3	charing_cross	shadow	['metal']

# %%
for meta in found:
    if 'black_metal' in meta['genres'] or 'death_metal' in meta['genres']:
        print('\n\n', meta)
# Out:
#  {'song_name': 'leviticus', 'artist_name': 'rwake', 'mp3_zipname': '1', 'mp3_filename': 'std_c0878c4c03e671ad4e219c6cb7321e67.mp3', 'genres': ['black_metal', 'progressive', 'southern_rock']}
#
#
#  {'song_name': 'into_death', 'artist_name': 'curriculum_mortis', 'mp3_zipname': '1', 'mp3_filename': 'std_8821d641f8970501f3873cfdfabc912d.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'ele', 'artist_name': 'mosquitos', 'mp3_zipname': '1', 'mp3_filename': 'std_2c9f1a491d4c570428c631df2a446416.mp3', 'genres': ['grime', 'ghettotech', 'death_metal']}
#
#
#  {'song_name': 'benedicto_xvi', 'artist_name': 'sophya', 'mp3_zipname': '1', 'mp3_filename': 'std_3be8bca056166e0b57bb1f75e3655685.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'cankerous', 'artist_name': 'bane_of_existence', 'mp3_zipname': '1', 'mp3_filename': 'std_d35af2c0635c37bb26be419ae5a7416e.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'sodomized_by_god', 'artist_name': 'willow_wisp?(rip_traci-a_true_drum_god!)', 'mp3_zipname': '1', 'mp3_filename': 'std_718dc6290b8158fd56d3d361fa9da4d4.mp3', 'genres': ['metal', 'black_metal', 'gothic']}
#
#
#  {'song_name': 'the_proliferation', 'artist_name': 'liar_of_golgotha', 'mp3_zipname': '1', 'mp3_filename': 'std_1b40d28301b869a71646145f53b20937.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'blestem', 'artist_name': 'vokodlok', 'mp3_zipname': '1', 'mp3_filename': 'std_22a0fc49bcfd40aeedc64a6ecff50261.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'goatflesh_removal_ii', 'artist_name': 'amok', 'mp3_zipname': '1', 'mp3_filename': 'std_deb4f368e3f14726f36779a0d845feaa.mp3', 'genres': ['death_metal', 'black_metal', 'industrial']}
#
#
#  {'song_name': 'terrorizer', 'artist_name': 'dispatched', 'mp3_zipname': '1', 'mp3_filename': 'std_a32c95d85dda871a796b55aaf4d99207.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'ananda', 'artist_name': 'rudra', 'mp3_zipname': '1', 'mp3_filename': 'std_3203de74b4b7a53e86b0d110ae1411d0.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'bastard_son', 'artist_name': 'watch_them_die', 'mp3_zipname': '1', 'mp3_filename': 'std_bd5fe743f7bdc587598438ce65930b21.mp3', 'genres': ['hardcore', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'sodomizing_the_exhumed', 'artist_name': 'sepsism', 'mp3_zipname': '1', 'mp3_filename': 'std_eb05719cb6f9db617e5ebb958977baed.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'the_fight', 'artist_name': 'inhumate_(in_studio)', 'mp3_zipname': '1', 'mp3_filename': 'std_b767e5fdca3859260c6c81cfa38286f2.mp3', 'genres': ['grindcore', 'death_metal']}
#
#
#  {'song_name': 'drink', 'artist_name': 'deformity', 'mp3_zipname': '1', 'mp3_filename': 'std_9d0dd086b3e9d4943315ae8f062aa92a.mp3', 'genres': ['grindcore', 'death_metal', 'punk']}
#
#
#  {'song_name': '30_seconds_of_fury', 'artist_name': 'ichorid_(is_coming_back?)', 'mp3_zipname': '1', 'mp3_filename': 'std_0cee0ca39583bbdc822704c568d67d4e.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'screams_from_the_disemboweled', 'artist_name': 'artery__eruption', 'mp3_zipname': '1', 'mp3_filename': 'std_21c253e29eb07323e2a1177346717c4f.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'the_highgate', 'artist_name': 'epoch_of_unlight', 'mp3_zipname': '1', 'mp3_filename': 'std_b86ee23ee9b8e510835ea9569d2d0ffa.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'kiss_the_snake', 'artist_name': 'graves_of_valor_(writing_new_music)', 'mp3_zipname': '1', 'mp3_filename': 'std_d1f83acbbbdcb37c2a62f94a8c8aa268.mp3', 'genres': ['death_metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'infernal_divinity', 'artist_name': 'triumphator', 'mp3_zipname': '1', 'mp3_filename': 'std_81047621bbb8b292196b94ac4db16358.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'death_dies', 'artist_name': 'death_dies', 'mp3_zipname': '1', 'mp3_filename': 'std_8fcbdf7644e7381bc477add0b20fe0ef.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'hardcore', 'artist_name': 'agallah_don_bishop', 'mp3_zipname': '1', 'mp3_filename': 'std_37e0585183408fe6051c2b9a399c7e81.mp3', 'genres': ['hip_hop', 'r&b', 'death_metal']}
#
#
#  {'song_name': 'drowned_in_the_dark', 'artist_name': 'imperceptible_fragment', 'mp3_zipname': '1', 'mp3_filename': 'std_622932358967637e0dffb944a298c408.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'supreme_infernal_legions', 'artist_name': 'luciferian_recording_new_album', 'mp3_zipname': '1', 'mp3_filename': 'std_349675ce1416723e3b19f24277bb964a.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'shit_machine', 'artist_name': 'the_mantors_(more_music)_ã\x82â©ã\x82â®', 'mp3_zipname': '1', 'mp3_filename': 'std_0c5dc1e2176583dcd2bdb6c80327bd92.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': "happiness_hotel_muppet's", 'artist_name': 'nostrilsaurus', 'mp3_zipname': '1', 'mp3_filename': 'std_c3aeea7d0edf7a8b6e7c1e4cf4be4d27.mp3', 'genres': ['black_metal', 'punk', 'ska']}
#
#
#  {'song_name': 'brother_ali', 'artist_name': 'cheap_cologne_ã\x82â©', 'mp3_zipname': '1', 'mp3_filename': 'std_76602eb46b4bb29db96052f7cf47bde0.mp3', 'genres': ['hip_hop', 'hyphy', 'death_metal']}
#
#
#  {'song_name': 'cannibal_communion', 'artist_name': 'schloss_tegal', 'mp3_zipname': '1', 'mp3_filename': 'std_ea8d3c2805c3b5525588ba2f76d181b3.mp3', 'genres': ['death_metal', 'experimental', 'industrial']}
#
#
#  {'song_name': 'world_of_shit', 'artist_name': 'divine_rapture', 'mp3_zipname': '1', 'mp3_filename': 'std_1dd08c2eb12294748f69c97f159ba4c8.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'nebelmond', 'artist_name': 'sun_of_the_sleepless', 'mp3_zipname': '1', 'mp3_filename': 'std_058328f062c086c2b2f26b6374865991.mp3', 'genres': ['ambient', 'black_metal']}
#
#
#  {'song_name': 'maggot_infestator', 'artist_name': 'absolute_defiance', 'mp3_zipname': '1', 'mp3_filename': 'std_9801ba57561615b480097a8b806978c0.mp3', 'genres': ['death_metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'structural_deceit', 'artist_name': 'detonation', 'mp3_zipname': '1', 'mp3_filename': 'std_25edab92f3ecf1f9a13bbbaee8ba200f.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'enemigo', 'artist_name': 'undercroft', 'mp3_zipname': '1', 'mp3_filename': 'std_f442de2f528a1c7b40e38c3009ce3b88.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'entropy_instrumental', 'artist_name': 'northwind', 'mp3_zipname': '1', 'mp3_filename': 'std_ab5d5530281510cdf223425a37b845e7.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'fragile_caress', 'artist_name': 'dark_lunacy', 'mp3_zipname': '1', 'mp3_filename': 'std_7a308c877c72a877894917f4178da0ef.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'firestorms', 'artist_name': 'demonoid', 'mp3_zipname': '1', 'mp3_filename': 'std_279f687ca74c48c29522f1c1e173145c.mp3', 'genres': ['death_metal', 'thrash']}
#
#
#  {'song_name': 'the_challenge', 'artist_name': 'slow_grind', 'mp3_zipname': '1', 'mp3_filename': 'std_8100f571c021847e858e261ada270b4f.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'manhandle_your_vagina', 'artist_name': 'e.t.t.s.__is_dead!', 'mp3_zipname': '1', 'mp3_filename': 'std_3359dd5d2a6245227e831f676f930816.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'return_to_chaos', 'artist_name': 'mephiztophel', 'mp3_zipname': '1', 'mp3_filename': 'std_cd89cef2867bdb2cdb5a1ea6b2437be6.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'arranging_self', 'artist_name': 'the_blackest_grey_&quot;recording_promo_2008&quot;', 'mp3_zipname': '1', 'mp3_filename': 'std_541b8c43d069c4d9da7596f78399c1cd.mp3', 'genres': ['hardcore', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'morgagnic_anatomics', 'artist_name': 'the_county_medical_examiners', 'mp3_zipname': '1', 'mp3_filename': 'std_23c5de737a86e8c8c835617aa8d0ea6e.mp3', 'genres': ['grindcore', 'death_metal']}
#
#
#  {'song_name': 'the_legion_that_will_never_fal', 'artist_name': 'hirilorn', 'mp3_zipname': '1', 'mp3_filename': 'std_3b26983ff9d11759f0d4ed06aa6fa4ed.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'lords_misrule', 'artist_name': 'ramesses', 'mp3_zipname': '1', 'mp3_filename': 'std_6940871f21150b11f49541a3a9d280e5.mp3', 'genres': ['psychedelic', 'experimental', 'black_metal']}
#
#
#  {'song_name': 'sovereignty_of_the_ancient', 'artist_name': 'mysteriarch', 'mp3_zipname': '1', 'mp3_filename': 'std_ad74383754928f82238cb030e0ceaf2c.mp3', 'genres': ['black_metal', 'black_metal', 'black_metal']}
#
#
#  {'song_name': 'cp__cp_unity', 'artist_name': 'cap_pun_kills_the_mic!', 'mp3_zipname': '1', 'mp3_filename': 'std_c56f17b40865f092df4cb7695418b369.mp3', 'genres': ['hip_hop', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'hands_of_oppressors', 'artist_name': 'warcrimes', 'mp3_zipname': '1', 'mp3_filename': 'std_8bfaedd5e80a018919133a21a4063248.mp3', 'genres': ['death_metal', 'punk', 'thrash']}
#
#
#  {'song_name': 'blood_for_blood_old_shit', 'artist_name': 'krimson_reign', 'mp3_zipname': '1', 'mp3_filename': 'std_49b740281d667bbdbf5d724bda6f0e9b.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'torture_of_the_saints', 'artist_name': 'hell_militia', 'mp3_zipname': '1', 'mp3_filename': 'std_a2d95e73558c206afebef474f71783be.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'disembodied', 'artist_name': 'rottrevore', 'mp3_zipname': '1', 'mp3_filename': 'std_631a545649176a7320967478a45d5eb5.mp3', 'genres': ['grindcore', 'death_metal']}
#
#
#  {'song_name': 'time_pt2_2006', 'artist_name': 'decemberance_(in_search_of_label...)', 'mp3_zipname': '1', 'mp3_filename': 'std_5725ce7fc6bdeca2eef418d09a24847b.mp3', 'genres': ['death_metal', 'experimental', 'down-tempo']}
#
#
#  {'song_name': 'boxcutter_facelift', 'artist_name': 'the_sawtooth_grin', 'mp3_zipname': '1', 'mp3_filename': 'std_d2fda2e1f485a1c5890362c695b98daf.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'small_world', 'artist_name': 'catafalc', 'mp3_zipname': '1', 'mp3_filename': 'std_82e94d52404255ad519c0bdf1f7eddd8.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'returning_to_misery_andcomfort', 'artist_name': 'sargeist', 'mp3_zipname': '1', 'mp3_filename': 'std_638bd1577ad5cb47039c057f670b9c2f.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'lice_crawling_humanity', 'artist_name': 'watchmaker', 'mp3_zipname': '1', 'mp3_filename': 'std_23d06776e58f5bdde61750b66a427f3b.mp3', 'genres': ['metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'harbinger_of_cataclysm', 'artist_name': 'law_of_the_vital_few_(new_songs!)', 'mp3_zipname': '1', 'mp3_filename': 'std_8212d5193c0824cf46fc81300a671e4b.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'awakening_of_the_emperor', 'artist_name': 'theudho', 'mp3_zipname': '1', 'mp3_filename': 'std_51c65aef6b8c61ba947bd131c4a8eb92.mp3', 'genres': ['metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'shadow_and_dust', 'artist_name': 'herfst_-_new_songs!', 'mp3_zipname': '1', 'mp3_filename': 'std_b6a41a2ac9c80bd791bfcc98e4102f25.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'penile_vacation', 'artist_name': 'penile_suffocation', 'mp3_zipname': '1', 'mp3_filename': 'std_b3f702a8c84b7f2af288ee9de362f0ae.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'coprophaggot_spermanizer', 'artist_name': 'penile_suffocation', 'mp3_zipname': '1', 'mp3_filename': 'std_9deee7d09f3279b99e27edcf79371056.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'now_ruin_is', 'artist_name': 'bird_of_ill_omen', 'mp3_zipname': '1', 'mp3_filename': 'std_b6ee5d5d78314018b7a93c7eea481ad6.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'the_dome_of_electric_karma', 'artist_name': 'neoplasmah', 'mp3_zipname': '1', 'mp3_filename': 'std_9f78b6fe82724cc0232489e56233acee.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'mother_earth', 'artist_name': 'alamogordo', 'mp3_zipname': '1', 'mp3_filename': 'std_c0b9c3db41e1789e62e04ee9109e8f47.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'a_longing_for_home', 'artist_name': 'vitriol_(final_show_tba!!!)', 'mp3_zipname': '1', 'mp3_filename': 'std_cc39c1c4a1eb6162ef0af5cb82d235d1.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'ludo_game', 'artist_name': 'sinners_bleed_-_searching_for_a_label', 'mp3_zipname': '1', 'mp3_filename': 'std_be9331592ec307e72d4e5ef9c3715e6f.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'siamese_sluts_of_fused_flesh', 'artist_name': 'intense_hammer_rage', 'mp3_zipname': '1', 'mp3_filename': 'std_421de86e9faf2f293c50ac8bfb8e4265.mp3', 'genres': ['death_metal', 'christian_rap', 'hawaiian']}
#
#
#  {'song_name': 'vaginal_hemophilia', 'artist_name': 'leukorrhea', 'mp3_zipname': '1', 'mp3_filename': 'std_402a7b59d59373fc69b3a2a7044149a8.mp3', 'genres': ['other', 'metal', 'death_metal']}
#
#
#  {'song_name': 'aeg_argata', 'artist_name': 'loits', 'mp3_zipname': '1', 'mp3_filename': 'std_3c893d03e697dbb4ac7b379134be6701.mp3', 'genres': ['metal', 'rock', 'black_metal']}
#
#
#  {'song_name': 'the_virus', 'artist_name': 'dxm_is_now_mtm', 'mp3_zipname': '1', 'mp3_filename': 'std_874da786fc32929a14296bfd9550330b.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'open_concave_chest_wounds', 'artist_name': 'terminally_your_aborted_ghost_(r.i.p.)', 'mp3_zipname': '1', 'mp3_filename': 'std_ba80b80892d82371fed672c91cb3dd47.mp3', 'genres': ['grindcore', 'hardcore', 'death_metal']}
#
#
#  {'song_name': '5__haircut', 'artist_name': 'bash!', 'mp3_zipname': '1', 'mp3_filename': 'std_87c27b0cd8f02b4f057ffee7f135d3c5.mp3', 'genres': ['indie', 'death_metal', 'punk']}
#
#
#  {'song_name': 'cryotron_frequency', 'artist_name': 'in-quest_(in_writing_mode)', 'mp3_zipname': '1', 'mp3_filename': 'std_059957f568611a216f7277f98b06399e.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'freedom_fighters', 'artist_name': 'cauterized', 'mp3_zipname': '1', 'mp3_filename': 'std_0f0194fd4295b9fc9e50d1155cf401a6.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'keep_it_in_mind', 'artist_name': 'jason_kocol', 'mp3_zipname': '1', 'mp3_filename': 'std_5a7c1bdddaa3628c5c72c992ad24eee6.mp3', 'genres': ['other', 'death_metal', 'folk']}
#
#
#  {'song_name': 'arterial______________excerpt', 'artist_name': 'mastabah', 'mp3_zipname': '1', 'mp3_filename': 'std_65829c50ee352b16b4649eb6455e1e4c.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'stronger', 'artist_name': 'sweet_silence', 'mp3_zipname': '1', 'mp3_filename': 'std_c94d2346ca5f7376edcab64777b19895.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'muerte_a_la_humanidad', 'artist_name': 'in_articulo_mortis', 'mp3_zipname': '1', 'mp3_filename': 'std_d17122af2a798848a9e44d44f436b7aa.mp3', 'genres': ['metal', 'death_metal', 'death_metal']}
#
#
#  {'song_name': 'sagittarius', 'artist_name': 'gorath', 'mp3_zipname': '1', 'mp3_filename': 'std_8b03ca26e6273f7fc212cc476eab70ad.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'terror_aus_fleisch_und_blut', 'artist_name': 'silberbach', 'mp3_zipname': '1', 'mp3_filename': 'std_040688fa763fae7b634b7f7300c89bcd.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'funeral_fog', 'artist_name': 'mayhem', 'mp3_zipname': '1', 'mp3_filename': 'std_a8a71db1b073f78236f0543b0a3a5cff.mp3', 'genres': ['metal', 'black_metal']}
#
#
#  {'song_name': 'monumento_samples', 'artist_name': 'dakrya_(debut_album_out_now!!)', 'mp3_zipname': '1', 'mp3_filename': 'std_cd8d9f0c03db01c88be02d7af70b25ad.mp3', 'genres': ['black_metal', 'gothic', 'classical_-_opera_and_vocal']}
#
#
#  {'song_name': 'a_day_of_rest', 'artist_name': 'end-time_illusion_(dialysis_is_imminent)', 'mp3_zipname': '1', 'mp3_filename': 'std_3116545b61fa69b0a99c6a767d552e0d.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'in_your_eyes', 'artist_name': '60_grit', 'mp3_zipname': '1', 'mp3_filename': 'std_0d79adf8a122c33e2b4d8d5d7520f5ce.mp3', 'genres': ['metal', 'death_metal', 'southern_rock']}
#
#
#  {'song_name': 'purging_decayed_afterlife', 'artist_name': 'grotesque_formation', 'mp3_zipname': '1', 'mp3_filename': 'std_2c6aa1d25eab1f6428312b1f89b05362.mp3', 'genres': ['grindcore', 'death_metal', 'lounge']}
#
#
#  {'song_name': 'goat_and_gazelle', 'artist_name': 'kodiak_bear_regiment', 'mp3_zipname': '1', 'mp3_filename': 'std_979b4d76b362d0e264153fef80fd5604.mp3', 'genres': ['metal', 'screamo', 'death_metal']}
#
#
#  {'song_name': 'intestine_jigsaw_puzzle', 'artist_name': 'acrid_asphyxiation_(rip)', 'mp3_zipname': '1', 'mp3_filename': 'std_01be1a490d6a169801e864080b962244.mp3', 'genres': ['grindcore', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'blind_victim', 'artist_name': 'pyuria_-_searching_drummer_&_new_song_online!!!', 'mp3_zipname': '1', 'mp3_filename': 'std_416c24d48e19b37bf80bca468a507485.mp3', 'genres': ['grindcore', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'zuriaake', 'artist_name': 'pest_productions', 'mp3_zipname': '1', 'mp3_filename': 'std_0e47e9436afa8caa6ebdb3dbff72044a.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'raptures', 'artist_name': 'stand_aside_(2002-2006_dead)', 'mp3_zipname': '1', 'mp3_filename': 'std_e379267ed5bf0e48a76261c40c129277.mp3', 'genres': ['metal', 'death_metal']}
#
#
#  {'song_name': 'living_fleshthrone', 'artist_name': 'temple_of_baal', 'mp3_zipname': '1', 'mp3_filename': 'std_01314a7de97020d6e9ed1f03f8023ebd.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'flames_of_baal', 'artist_name': 'temple_of_baal', 'mp3_zipname': '1', 'mp3_filename': 'std_c1780078bf8e5beef4fe40e8f8c92c2f.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'persistant_genital_warts', 'artist_name': 'necrocest', 'mp3_zipname': '1', 'mp3_filename': 'std_6e7cd5291721b8c8340528d14f421b44.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'bunny_slope', 'artist_name': 'coughs', 'mp3_zipname': '1', 'mp3_filename': 'std_dda2d372199bf08f98602224bdb18d4e.mp3', 'genres': ['experimental', 'big_beat', 'black_metal']}
#
#
#  {'song_name': 'architects_of_downfall', 'artist_name': 'taste_of_tears_[writing_new_songs]', 'mp3_zipname': '1', 'mp3_filename': 'std_efd0109cedb1964c432a7eff0e567a67.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': "sample_on_wind's_wings", 'artist_name': 'dhaubgurz', 'mp3_zipname': '1', 'mp3_filename': 'std_e542488c7d0a44ab4d438ae83d521cd7.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'judgment_defiles', 'artist_name': 'warface', 'mp3_zipname': '1', 'mp3_filename': 'std_6af29f8388eb9aaa25b31a2adc17a46b.mp3', 'genres': ['metal', 'death_metal', 'healing_&_easylistening']}
#
#
#  {'song_name': 'frustration', 'artist_name': 'membranes_of_the_multiverse', 'mp3_zipname': '1', 'mp3_filename': 'std_01d41805d0565ad89b2bf0a2069e681d.mp3', 'genres': ['grindcore', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'call_of_the_wild', 'artist_name': 'forbidden_forest', 'mp3_zipname': '1', 'mp3_filename': 'std_e98a09957b205efc1ca25d2ddda659d5.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'ubermensch', 'artist_name': 'scorngrain', 'mp3_zipname': '1', 'mp3_filename': 'std_94a27d13db797e4f8af3ae355f027307.mp3', 'genres': ['death_metal', 'thrash', 'industrial']}
#
#
#  {'song_name': 'spikes_leather_and_bullets', 'artist_name': 'decayed', 'mp3_zipname': '1', 'mp3_filename': 'std_cb82f1061fc1ed1c14f3fb7b5ab1875c.mp3', 'genres': ['metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'chuck_connors', 'artist_name': 'wallmen', 'mp3_zipname': '1', 'mp3_filename': 'std_dcb876dfa197ea46e4203d257bbfb48a.mp3', 'genres': ['death_metal', 'melodramatic_popular_song', 'christian']}
#
#
#  {'song_name': "nothing_as_it's_going_to_be", 'artist_name': 'creeper_lagoon', 'mp3_zipname': '1', 'mp3_filename': 'std_4c14817eda5be2060873f69e05df156b.mp3', 'genres': ['soul', 'indie', 'death_metal']}
#
#
#  {'song_name': 'debauched_putrefaction', 'artist_name': 'malodorous', 'mp3_zipname': '1', 'mp3_filename': 'std_09304dec77586781f507a8b20af50427.mp3', 'genres': ['grindcore', 'death_metal', 'experimental']}
#
#
#  {'song_name': 'master_of_dread', 'artist_name': 'bartholomeus_night', 'mp3_zipname': '1', 'mp3_filename': 'std_c0098acede89c04851d716173914c9aa.mp3', 'genres': ['black_metal', 'black_metal', 'black_metal']}
#
#
#  {'song_name': 'over_active_appreciation', 'artist_name': 'vverevvolf_grehv', 'mp3_zipname': '1', 'mp3_filename': 'std_8a03089d59979054dd973a6ae88cd9e1.mp3', 'genres': ['death_metal', 'experimental', 'electronica']}
#
#
#  {'song_name': 'ruler', 'artist_name': 'vilkates', 'mp3_zipname': '1', 'mp3_filename': 'std_2796dcbcfd88281f495ee8949a928b62.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'this_art_is_suicide', 'artist_name': 'hegira_records', 'mp3_zipname': '1', 'mp3_filename': 'std_de16a927ad22ed1af0581a8befa52f3f.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'reverse_exorcism', 'artist_name': 'thy_legacy', 'mp3_zipname': '1', 'mp3_filename': 'std_e80035ae64d15ad7633dc440c91f9254.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'a_world_of_bones', 'artist_name': 'carpathian_forest', 'mp3_zipname': '1', 'mp3_filename': 'std_5374b3416348b2ef09cb823840e532b1.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': '44_magnum_opus', 'artist_name': 'exodus__-___(the_atrocity_exhibition__out_now!_)', 'mp3_zipname': '1', 'mp3_filename': 'std_3a78d1125a0cebcbb8545710b4bd063d.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'messiah_to_burn', 'artist_name': 'fermento', 'mp3_zipname': '1', 'mp3_filename': 'std_d2fa403820b6b5e62072ba0a98dc3f61.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'pursuit_of_vikings', 'artist_name': 'amon_amarth_-_new_song_up!', 'mp3_zipname': '1', 'mp3_filename': 'std_98747897d30eae3cca84d0c4b0f09219.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'demon_seed', 'artist_name': 'dead_emotions_[new_song_uploaded]', 'mp3_zipname': '1', 'mp3_filename': 'std_aac496e82a3ea1e4d8b06f4c22fa8340.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'silence', 'artist_name': 'dungortheb_(searching_dates_!!!)', 'mp3_zipname': '1', 'mp3_filename': 'std_c0518a7137546b023474d2dbe144e8ad.mp3', 'genres': ['metal', 'death_metal']}
#
#
#  {'song_name': 'premature_burial', 'artist_name': 'malevolent_creation', 'mp3_zipname': '1', 'mp3_filename': 'std_078c3c025d47f241c57c054f1b846cd7.mp3', 'genres': ['death_metal', 'thrash']}
#
#
#  {'song_name': 'the_greatest_trick', 'artist_name': 'conspiracy_a.d._new_blog_up!', 'mp3_zipname': '1', 'mp3_filename': 'std_914174babf5deb8e6a5864bf99f525a8.mp3', 'genres': ['hardcore', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'thurs', 'artist_name': 'gjenferdsel', 'mp3_zipname': '1', 'mp3_filename': 'std_cd01d0fe6361f924458668c06e975a0f.mp3', 'genres': ['metal', 'folk', 'black_metal']}
#
#
#  {'song_name': 'hypnotic_spasm', 'artist_name': 'level_above_human_(live_pics_online!)', 'mp3_zipname': '1', 'mp3_filename': 'std_8668e6b20fe579f66cea443418071406.mp3', 'genres': ['grindcore', 'death_metal']}
#
#
#  {'song_name': 'mortification', 'artist_name': 'insanity_(auditioning_bassists)', 'mp3_zipname': '1', 'mp3_filename': 'std_7c302f1c282c06f38e86eb73f4ca3937.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'ubel_katzchen_remix', 'artist_name': 'typozorg', 'mp3_zipname': '1', 'mp3_filename': 'std_a9dffa12376d0253f470527cf8806eb0.mp3', 'genres': ['death_metal', 'experimental', 'industrial']}
#
#
#  {'song_name': 'undine_sey_meyn_schutzgeyst', 'artist_name': 'eden_weint_im_grab', 'mp3_zipname': '1', 'mp3_filename': 'std_0058505adce0279aaf5a6f528aebc516.mp3', 'genres': ['metal', 'black_metal', 'gothic']}
#
#
#  {'song_name': 'raw', 'artist_name': 'flesh_consumed_(album_out_now!!)', 'mp3_zipname': '1', 'mp3_filename': 'std_b2ae0110aa8cf9cf6a3ce006acd4ab93.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'unnamed_quintessence_of_grimne', 'artist_name': 'enthroning_silence', 'mp3_zipname': '1', 'mp3_filename': 'std_4e2d7cf5205562b4f8a5bd3be5c9782c.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'piano_lessons_can_be_murder', 'artist_name': 'dr._acula_{buy_our_cd_today!_}', 'mp3_zipname': '1', 'mp3_filename': 'std_e83cf420f9a3e30c5883333643967819.mp3', 'genres': ['grindcore', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'seelenfest', 'artist_name': 'procton', 'mp3_zipname': '1', 'mp3_filename': 'std_e7d51dc9ed85561d7bfdfeb854dc2ad3.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'apoplectic', 'artist_name': 'ainmatter', 'mp3_zipname': '1', 'mp3_filename': 'std_21514a063f0fea72c62e6faa24f41739.mp3', 'genres': ['metal', 'death_metal', 'drum_&_bass']}
#
#
#  {'song_name': 'conscious_in_rigor_mortis', 'artist_name': 'putridity_-_m.o.d._pics_up!!!!', 'mp3_zipname': '1', 'mp3_filename': 'std_65aabe18865e90cf1fde249652c942e8.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'double_anal_penetration_in', 'artist_name': 'rotten_penetration', 'mp3_zipname': '1', 'mp3_filename': 'std_f9f1d648a3973bc8bb2209247920fe90.mp3', 'genres': ['grindcore', 'death_metal']}
#
#
#  {'song_name': 'reborn_by_the_moons_light2006', 'artist_name': 'blackstream', 'mp3_zipname': '1', 'mp3_filename': 'std_c9c3ae9f09517b42b80557b4b28db1fe.mp3', 'genres': ['experimental', 'ambient', 'black_metal']}
#
#
#  {'song_name': 'monument_to_the_dead', 'artist_name': 'necronoclast', 'mp3_zipname': '1', 'mp3_filename': 'std_1669271da38a98c7ceb371f26d64efbd.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'sounds_from_a_dying_planet', 'artist_name': 'mechanical_chaos', 'mp3_zipname': '1', 'mp3_filename': 'std_91942f0d7bd2b5d857045df6b4e9678a.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'sodomie', 'artist_name': 'knochenbruch_(suche_drummer!!!)', 'mp3_zipname': '1', 'mp3_filename': 'std_9b8a6996395ab80ced24dad9016a0704.mp3', 'genres': ['death_metal', 'black_metal', 'gothic']}
#
#
#  {'song_name': 'beyond_the_circle', 'artist_name': 'excruciate', 'mp3_zipname': '1', 'mp3_filename': 'std_f4f051bf91d2766da9bc5c198a09411c.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': '1837', 'artist_name': 'a_ravens_forest', 'mp3_zipname': '1', 'mp3_filename': 'std_404d78892c4456340d40c624ba03f60e.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'departure', 'artist_name': 'theory_in_practice_(two_new_songs_up)', 'mp3_zipname': '1', 'mp3_filename': 'std_b1d668aacfbd4ed729391ebb9e6ce85a.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'autopsy', 'artist_name': 'operating_table', 'mp3_zipname': '1', 'mp3_filename': 'std_76005b5e24933b64a5a141996d881d14.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'thunder_of_hoof_and_steel', 'artist_name': 'horn_of_dagoth', 'mp3_zipname': '1', 'mp3_filename': 'std_306f3a3cc512eadf9e17d4b6ecde43df.mp3', 'genres': ['metal', 'black_metal', 'black_metal']}
#
#
#  {'song_name': 'manchurian_candidates', 'artist_name': 'the_bleedout', 'mp3_zipname': '1', 'mp3_filename': 'std_1cc3c133a3a88ce3dcb11e6191a8b3d7.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'black_disharmonium', 'artist_name': 'helmskey_(has_a_song_up!)', 'mp3_zipname': '1', 'mp3_filename': 'std_0a2e536733c0b6bffee09f23d69a300f.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'gialo', 'artist_name': 'katalepsy', 'mp3_zipname': '1', 'mp3_filename': 'std_c9de494d58bf4e9bed552479bf44945a.mp3', 'genres': ['death_metal']}
#
#
#  {'song_name': 'cold_teeth_sing_out', 'artist_name': 'the_tyrant_of_manchester', 'mp3_zipname': '1', 'mp3_filename': 'std_2dfeda796cc1a4574798c8b0c2229512.mp3', 'genres': ['psychedelic', 'experimental', 'black_metal']}
#
#
#  {'song_name': 'heaven_and_lies_edit', 'artist_name': 'deathtiny', 'mp3_zipname': '1', 'mp3_filename': 'std_a0f74b72ee32c5cce080225f65de4584.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'caravan_of_plague_bearers', 'artist_name': 'faustcoven', 'mp3_zipname': '1', 'mp3_filename': 'std_124aa1e78246efb512e9dbc3efc78d54.mp3', 'genres': ['metal', 'down-tempo', 'black_metal']}
#
#
#  {'song_name': 'beav', 'artist_name': 'stephen_tanner', 'mp3_zipname': '1', 'mp3_filename': 'std_ce7dfd8f90cba6e7457f25bcd04bcd75.mp3', 'genres': ['death_metal', 'black_metal', 'hawaiian']}
#
#
#  {'song_name': 'der_erste_nachtfrost', 'artist_name': 'drautran', 'mp3_zipname': '1', 'mp3_filename': 'std_4f75fd75b0a92dbfc33cb0e6e091baec.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'waiting_for_the_wind', 'artist_name': 'daedeloth', 'mp3_zipname': '1', 'mp3_filename': 'std_7bb9ab274675e82a1bafcae4608de961.mp3', 'genres': ['metal', 'death_metal']}
#
#
#  {'song_name': 'masquerading_as_the_almighty', 'artist_name': 'premature_burial', 'mp3_zipname': '1', 'mp3_filename': 'std_7d064264c7ed6a1ccfd068bd3404994e.mp3', 'genres': ['metal', 'grindcore', 'death_metal']}
#
#
#  {'song_name': 'decimating_the_decaying_orific', 'artist_name': 'bowels_out_[blasting_guttural_sickness]_nydm', 'mp3_zipname': '1', 'mp3_filename': 'std_db67f71e79659d31a0b923508db343be.mp3', 'genres': ['death_metal', 'death_metal', 'death_metal']}
#
#
#  {'song_name': 'soul_kept_bearers', 'artist_name': 'dm3_productions_inc.', 'mp3_zipname': '1', 'mp3_filename': 'std_dfcf4cf63c188207554755f859c12a41.mp3', 'genres': ['metal', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'aurora_borealis', 'artist_name': 'gungnir', 'mp3_zipname': '1', 'mp3_filename': 'std_b950ddc10a4c3569a29a57253bb3a883.mp3', 'genres': ['black_metal', 'black_metal', 'black_metal']}
#
#
#  {'song_name': 'obsessed_with_an_idea', 'artist_name': 'tears_of_kali', 'mp3_zipname': '1', 'mp3_filename': 'std_60f902cda92c5e9f39626d683a560676.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'the_explorer', 'artist_name': 'vintersorg', 'mp3_zipname': '1', 'mp3_filename': 'std_b0317cf9e69e6baaf0ec274b75951bcc.mp3', 'genres': ['folk', 'black_metal', 'progressive']}
#
#
#  {'song_name': 'i_despise_you', 'artist_name': 'smashed_face_-_looking_for_second_cd_reedition!', 'mp3_zipname': '1', 'mp3_filename': 'std_4cff23aa13e6c72b8d042580574adbf1.mp3', 'genres': ['grindcore', 'hardcore', 'death_metal']}
#
#
#  {'song_name': 'vengeance_is_hers', 'artist_name': 'satariel', 'mp3_zipname': '1', 'mp3_filename': 'std_acdd21090d75ab225115e9d397151339.mp3', 'genres': ['metal', 'death_metal', 'progressive']}
#
#
#  {'song_name': 'hey_dont_ask_me_man', 'artist_name': 'lv-42666', 'mp3_zipname': '1', 'mp3_filename': 'std_810aa25254ea0634e8e16bc88287a9b2.mp3', 'genres': ['grindcore', 'death_metal', 'gothic']}
#
#
#  {'song_name': 'the_hordes_of_satan', 'artist_name': 'thy_infernal', 'mp3_zipname': '1', 'mp3_filename': 'std_ac9d93ec83f1da3132221e83dac29e06.mp3', 'genres': ['metal', 'death_metal', 'black_metal']}
#
#
#  {'song_name': 'blood_libels', 'artist_name': 'antaeus', 'mp3_zipname': '1', 'mp3_filename': 'std_038fcda9b1fc4ae60143f99e89017b3b.mp3', 'genres': ['black_metal']}
#
#
#  {'song_name': 'the_heritage_from_the_past', 'artist_name': 'tartaros', 'mp3_zipname': '1', 'mp3_filename': 'std_ba16bf3f8f26798a505af59992725e93.mp3', 'genres': ['experimental', 'black_metal']}
#
#
#  {'song_name': 'necrosodomizer', 'artist_name': 'deathwitch', 'mp3_zipname': '1', 'mp3_filename': 'std_0e02fdf682e8b6e4bedc303120b801eb.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'le_baptistere', 'artist_name': 'la_rumeur_des_chaines', 'mp3_zipname': '1', 'mp3_filename': 'std_310ace88e012e9a3348d506a567ee820.mp3', 'genres': ['metal', 'black_metal']}
#
#
#  {'song_name': 'death_of_heaven', 'artist_name': 'infernal_majesty', 'mp3_zipname': '1', 'mp3_filename': 'std_e5eefd4f8512fff227387136cf858098.mp3', 'genres': ['metal', 'death_metal', 'thrash']}
#
#
#  {'song_name': 'activate_the_anarchus', 'artist_name': 'abominator', 'mp3_zipname': '1', 'mp3_filename': 'std_ba62a6807e1d0fad7041ec9b4774c8fe.mp3', 'genres': ['death_metal', 'black_metal', 'thrash']}
#
#
#  {'song_name': 'when_silence_is_broken', 'artist_name': 'disbelief', 'mp3_zipname': '1', 'mp3_filename': 'std_bcbbf64300876f6d28a5d724362e9737.mp3', 'genres': ['metal', 'death_metal']}

# %%
#_-_new_song_up! _(searching_dates_!!!)  _new_blog_up!  _(live_pics_online!)  _(auditioning_bassists)
# _(album_out_now!!)  _{buy_our_cd_today!_}   _pics_up!!!!  _(suche_drummer!!!)   _(two_new_songs_up)
#_(has_a_song_up!)  _-_looking_for_second_cd_reedition!  __-___(the_atrocity_exhibition__out_now!_)
#_[writing_new_songs]  _-_searching_drummer_&_new_song_online!!!  _(debut_album_out_now!!)
#_(in_writing_mode)  _(r.i.p.) _-_searching_for_a_label  _(final_show_tba!!!)  _-_new_songs!  _(new_songs!)
#_(in_search_of_label...)  _recording_new_album  _(writing_new_music)  _(is_coming_back?)  _(in_studio)

# %%
#fp = '%s/1/std_b0317cf9e69e6baaf0ec274b75951bcc.mp3' % myspace_mp3s_path
fp = '%s/1/std_cd01d0fe6361f924458668c06e975a0f.mp3' % myspace_mp3s_path
metadata = mediainfo(fp).get('TAG', None)
metadata
# Out:
# {'encoder': 'LAME3.96r'}

# %%
def add_size_to_data(data, mp3s_path, metadata_path):
    ttl = 0
    not_found = []
    over_5mb = 0
    
    for i, fn in enumerate(data.keys()):
        if i and i%10000==0:
            print('Records checked so far: %d\tRecs found: %d\t> 5 Mb: %d\tNot Found: %d, including %s' % (
                i, ttl, over_5mb, len(not_found), not_found[-1]))
            with gzip.open(metadata_path, 'wt', encoding='utf-8') as oz:
                json.dump(data, oz)
                
        fp = '%s/%s' % (mp3s_path, fn)
        if not os.path.exists(fp):
            not_found.append(fn)
            continue
            
        ttl+=1
            
        data[fn]['size_mb'] = os.path.getsize(fp)/1024**2
        if data[fn]['size_mb'] > 5:
            over_5mb+=1
            
    return data

# %%
data = add_size_to_data(data, mp3s_path, metadata_path)
